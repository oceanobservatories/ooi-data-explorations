# %% [markdown]
# # Using M2M: Programmatic Interaction with OOI Data & Metadata
# Author: Andrew Reed
#
# ### Purpose
# This notebook is the companion to the presentation "**Other Methods**" presented as part of the Ocean Observatories Facilities Board **OOIFB Pioneer-MAB Array Community Workshop** in Norfolk, VA, from September 10 - 12, 2024. The goal is to walk through how to use the Ocean Observatories Initiative's API, named Machine-2-Machine (M2M), system and examine what data can be queried and how to manipulate it to extract desired information. The table below outlines the different categories of data which can be queried, their access points in the API, and a short description.
#
# | Category | Access Point | Description |
# | -------- | ------------ | ----------- |
# | Deployment | 12587/events/deployment/inv/ | Access deployment numbers as well as the asset & calibration info for specified instrument & deployment, and deployment times/cruises |
# | Deployment | 12587/asset/deployments | Asset & calibration info for all deployment for the specified UID |
# | Calibration | /12587/asset/cal?uid= OR ?assetid= | Return all calibration info for a given uid or assetId |
# | Calibration | /12587/asset/cal?refdes= | Return list of deployments with calibrations for a given reference designator |
# | Asset | 12587/asset?uid= OR ?serialnumber= | Asset information by unique id or instrument serial number |
# | Preload | 12575/parameter/ | Retrieve information for a parameter (i.e. variable) given its ID number |
# | Preload | 12575/stream/byname/ | Retrieve information for a stream given its name |
# | Annotations | /12580/anno/find?= | Retrieve annotations for a specific time period and for a given reference designator (optional: stream and method) |
# | Vocab | 12586/vocab/inv/ | Get the vocabulary (descriptions) for a sensor |
# | Data | 12576/sensor/inv/ | Can access the data from OOI using either a synchronous (returns JSON; limited to 20000 data points) or asynchronous (returns netCDF, CSV, or JSON; not data limit) |
#
# The tutorial and presentation are based off of similar work developed by Sage Lichtenwalder (github: @seagrinch) for the 2018 OOI Data Workshops.
#
# ### Setup
# First, please go to https://ooinet.oceanobservatories.org/ and make an account for yourself. Once you have registered and logged in, navigate to your account settings by clicking on "User Profile" under your email in the top right corner of your screen. Once at your Profile, record your API Username and API Token. These are necessary if you wish to access and download data from the Ocean Observatories API.
#
# Additionally, this notebook makes use of the code contained in the partner module pyOOI. A stripped-down version of this package has been included as a module in the repository with this tutorial to allow for direct import. Further code scripts and functions may also be found on github.com/oceanobservatories/ooi-data-explorations.

# %%
import os, sys
import yaml
import datetime
import requests
import pandas as pd
import xarray as xr
import warnings
warnings.filterwarnings("ignore")

# %%
from IPython.core.display import display, HTML
#display(HTML("<style>.container { width:100% !important; }</style>"))

# %% [markdown]
# Import the M2M module from the accompanying package if it is downloaded locally:

# %%
sys.path.append("../src/")
from pyOOI.M2M import *

# %%
for key in URLS.keys():
    dtype = key
    url = URLS.get(dtype)
    print(dtype + " :: " + url)
# Out:
# data :: https://ooinet.oceanobservatories.org/api/m2m/12576/sensor/inv
# anno :: https://ooinet.oceanobservatories.org/api/m2m/12580/anno/find
# vocab :: https://ooinet.oceanobservatories.org/api/m2m/12586/vocab/inv
# asset :: https://ooinet.oceanobservatories.org/api/m2m/12587
# deploy :: https://ooinet.oceanobservatories.org/api/m2m/12587/events/deployment/inv
# preload :: https://ooinet.oceanobservatories.org/api/m2m/12575/parameter
# cal :: https://ooinet.oceanobservatories.org/api/m2m/12587/asset/cal
# fileServer :: https://opendap.oceanobservatories.org/thredds/fileServer/
# dodsC :: https://opendap.oceanobservatories.org/thredds/dodsC/
# goldCopy :: https://thredds.dataexplorer.oceanobservatories.org/thredds/catalog/ooigoldcopy/public/
# goldCopy_fileServer :: https://thredds.dataexplorer.oceanobservatories.org/thredds/fileServer/
# goldCopy_dodsC :: https://thredds.dataexplorer.oceanobservatories.org/thredds/dodsC/

# %% [markdown]
# ---
# ## Navigating the API
# Navigating the OOI M2M end-points can be confusing. We can reference the helpful OOI API cheat-sheet. There are also several other quirks with how OOI delivers data. First, some queries to OOI will return . These are some basic functions needed to interoperate with the OOI data

# %%
def ntp_seconds_to_datetime(ntp_seconds):
    """Convert OOINet timestamps to unix-convertable timestamps."""
    # Specify some constant needed for timestamp conversions
    ntp_epoch = datetime.datetime(1900, 1, 1)
    unix_epoch = datetime.datetime(1970, 1, 1)
    ntp_delta = (unix_epoch - ntp_epoch).total_seconds()

    return datetime.datetime.utcfromtimestamp(ntp_seconds - ntp_delta)

def convert_time(ms):
    if ms is None:
        return None
    else:
        return datetime.datetime.utcfromtimestamp(ms/1000)

def unix_epoch_time(date_time):
    """Convert a datetime to unix epoch microseconds."""
    # Convert the date time to a string
    date_time = int(pd.to_datetime(date_time).strftime("%s"))*1000
    return date_time

# %% [markdown]
# ---
# ## Finding Data
#
# The first step in downloading data from the OOI M2M is to find the datasets that you want to download. We can do this by querying the "data" API through its various endpoints until we have the sensor that we are interested in.

# %%
# Start with the basic - just requesting the very basic gives you a list of the available sites - OOI parlance
# for the different moorings (i.e. Global Station Papa Flanking Mooring A = GP03FLMA)
print("API Endpoint: " + URLS["data"] + "\n")

print("Returns the following list of sites: \n")
sites = get_api(URLS["data"])
print(sites)
# Out:
# API Endpoint: https://ooinet.oceanobservatories.org/api/m2m/12576/sensor/inv
#
# Returns the following list of sites:
#
# ['CE01ISSM', 'CE01ISSP', 'CE02SHBP', 'CE02SHSM', 'CE02SHSP', 'CE04OSBP', 'CE04OSPD', 'CE04OSPI', 'CE04OSPS', 'CE04OSSM', 'CE05MOAS', 'CE06ISSM', 'CE06ISSP', 'CE07SHSM', 'CE07SHSP', 'CE09OSPM', 'CE09OSSM', 'CP01CNPM', 'CP01CNSM', 'CP01CNSP', 'CP02PMCI', 'CP02PMCO', 'CP02PMUI', 'CP02PMUO', 'CP03ISPM', 'CP03ISSM', 'CP03ISSP', 'CP04OSPM', 'CP04OSSM', 'CP05MOAS', 'CP10CNSM', 'CP11NOSM', 'CP11SOSM', 'CP12CNSW', 'CP12WESW', 'CP13EAPM', 'CP13NOPM', 'CP13SOPM', 'CP14NEPM', 'CP14SEPM', 'CP15MOAS', 'CP16MOAS', 'GA01SUMO', 'GA02HYPM', 'GA03FLMA', 'GA03FLMB', 'GA05MOAS', 'GI01SUMO', 'GI02HYPM', 'GI03FLMA', 'GI03FLMB', 'GI05MOAS', 'GP02HYPM', 'GP03FLMA', 'GP03FLMB', 'GP05MOAS', 'GS01SUMO', 'GS02HYPM', 'GS03FLMA', 'GS03FLMB', 'GS05MOAS', 'RS01OSBP', 'RS01SBPD', 'RS01SBPS', 'RS01SHBP', 'RS01SHDR', 'RS01SLBS', 'RS01SUM1', 'RS01SUM2', 'RS03ASHS', 'RS03AXBS', 'RS03AXPD', 'RS03AXPS', 'RS03AXSM', 'RS03CCAL', 'RS03ECAL', 'RS03INT1', 'RS03INT2', 'SSRSPACC']

# %%
# Select a site: Coastal Pioneer MAB Central Surface Mooring
site = "CP10CNSM"

# Can further narrow down the search - adding in the site will generate a list of the "nodes" on the mooring
print("API Endpoint: " + URLS["data"] + "/" + site + "\n")

print(f"Returns the following list of nodes on {site}: \n")
nodes = get_api(URLS["data"] + "/" + site)
print(nodes)
# Out:
# API Endpoint: https://ooinet.oceanobservatories.org/api/m2m/12576/sensor/inv/CP10CNSM
#
# Returns the following list of nodes on CP10CNSM:
#
# ['MFC31', 'MFD36', 'MFD37', 'RIC21', 'RID26', 'RID27', 'SBD11', 'SBD12']

# %%
# Select a node - in this case the multifunction node
node = "MFD37"

# Can further narrow the search - adding in the node with generate a list of the sensors on the given platform and node
print("API Endpoint: " + URLS["data"] + "/" + site + "/" + node + "\n")

# Next, we can get all of the sensors on a given mooring node
print(f"Returns the following list of sensors on {site}-{node}: \n")
sensors = get_api(URLS["data"] + "/" + site + "/" + node)
print(sensors)
# Out:
# API Endpoint: https://ooinet.oceanobservatories.org/api/m2m/12576/sensor/inv/CP10CNSM/MFD37
#
# Returns the following list of sensors on CP10CNSM-MFD37:
#
# ['00-DCLENG000', '01-OPTAAD000', '03-CTDBPC000', '04-DOSTAD000', '07-ZPLSCC000']

# %% [markdown]
# Here we can see there are four sensors on the Coastal Pioneer MAB Central Surface Mooring Multi-function node. One of the sensors (00-DCLENG000) returns engineering/operations data and does not have useful science data. The other three sensors are:
# * 00-DCLENG000 - engineering data
# * 01-OPTAAD000 - hyperspectrometer sensor
# * 03-CTDBPC000 - CTD data
# * 04-DOSTAD000 - Aanderaa dissolved oxygen optode
# * 07-ZPLSCC000 - Bio-Acoustic sonar

# %%
# Select a sensor - in this case the dissolved oxygen sensor
sensor = "04-DOSTAD000"

# With the site-node-sensors we can construct a "reference designator" or refdes for short
print(f"Site: {site}")
print(f"Node: {node}")
print(f"Sensor: {sensor}")
# Out:
# Site: CP10CNSM
# Node: MFD37
# Sensor: 04-DOSTAD000

# %% [markdown]
# With the **site**, **node**, and **sensor** we can construct the **reference designator** or **refdes** for short. The **reference designator** identifies a particular instrument that has been deployed as part of a site.

# %%
refdes = "-".join((site, node, sensor))
print(f"Reference Designator: {refdes}")
print(f"Site: {site}")
print(f"Node: {node}")
print(f"Sensor: {sensor}")
# Out:
# Reference Designator: CP10CNSM-MFD37-04-DOSTAD000
# Site: CP10CNSM
# Node: MFD37
# Sensor: 04-DOSTAD000

# %%
# With a sensor selected, we can see what data delivery methods are available
print("API Endpoint: " + URLS["data"] + "/" + site + "/" + node + "/" + sensor + "\n")

# Next, we can get all of the sensors on a given mooring node
print(f"Returns the following list of data delivery methods on {site}-{node}-{sensor}: \n")
methods = get_api(URLS["data"] + "/" + site + "/" + node + "/" + sensor)
print(methods)
# Out:
# API Endpoint: https://ooinet.oceanobservatories.org/api/m2m/12576/sensor/inv/CP10CNSM/MFD37/04-DOSTAD000
#
# Returns the following list of data delivery methods on CP10CNSM-MFD37-04-DOSTAD000:
#
# ['telemetered']

# %% [markdown]
# The **Data Delivery Method** specifies how the data was either transmitted or recorded. In this case, we only have the option:
# * **telemetered**: Data received through wireless transmission, e.g. surface buoy to satellite, glider to satellite, etc. Telemetered data is frequently truncated or decimated to reduce size for transmission.
#
# This is because this is the first deployment of MAB and we have not yet turned the mooring, so there is no recovered data available yet. In the future there will be **recovered_host** data stream available for the DOSTA, which is the data stored on the mooring computer. For instruments which self-log, there will also be a **recovered_inst** data stream with the data downloaded from the instrument.

# %%
# Select a data delivery method
method = "telemetered"

# Can further narrow the search - adding in the node with generate a list of the sensors on the given platform and node
print("API Endpoint: " + URLS["data"] + "/" + site + "/" + node + "/" + sensor + "/" + method + "\n")

# Next, we can get all of the sensors on a given mooring node
print(f"Returns the following list of streams for {site}-{node}-{sensor} {method}: \n")
sensors = get_api(URLS["data"] + "/" + site + "/" + node + "/" + sensor + "/" + method)
print(sensors)
# Out:
# API Endpoint: https://ooinet.oceanobservatories.org/api/m2m/12576/sensor/inv/CP10CNSM/MFD37/04-DOSTAD000/telemetered
#
# Returns the following list of streams for CP10CNSM-MFD37-04-DOSTAD000 telemetered:
#
# ['dosta_abcdjm_dcl_instrument']

# %% [markdown]
# The **Data Streams** are generated from parsing the sensor raw data and separating it based on content (e.g. science, engineering, metadata, etc.). In this case, we have the options:
# * **dosta_abcdjm_dcl_instrument**: this stream contains the science-relevant data we are interested in getting that is being telemetered
#
# Other science streams will become available once the sensors have been recovered following the first deployment recovery.

# %%
# Select the stream
stream = "dosta_abcdjm_dcl_instrument"

# %% [markdown]
# #### Search Datasets
#
# For your convience, the function ```search_datasets``` included in the tutorial package can search the available OOI Reference Designators (i.e. "refdes" for short) on the following keys: **array**, **node**, **instrument**. Additionally, can request for "**English_names**", which will return the descriptive name for the associated array, node, and instrument. The function uses the knowledge of the sensor endpoints outlined above to crawl through the endpoints looking for available datasets which fit the search keys. Below, we will search for the available turbidity instruments on the Coastal Pioneer MAB Central Surface Mooring. Adding the "**English_names**" make use of the **vocab** url which we'll explore in a section lower-down in this notebook.
#
# The major caveat with the search is, similar to when searching on ERDDAP datasets, the search terms must be partial or full match based on OOI nomenclature. For example, if we were looking for CTDs, we would have to search for "CTD", "CTDMO", or the full instrument name "02-CTDMOH051". We can't search "conductivity", "temperature" or other CTD-related instrument terms.
#
# We'll search the Coastal Pioneer MAB Central Surface Mooring Datasets for any turbidity sensors, all of which will start with "TU".

# %%
cnsm_datasets = search_datasets(array="CP10CNSM", instrument="DO", English_names=True)
cnsm_datasets
# Out:
# Searching https://ooinet.oceanobservatories.org/api/m2m/12576/sensor/inv/CP10CNSM
#       array                                   array_name   node  \
# 0  CP10CNSM  Coastal Pioneer MAB Central Surface Mooring  RID27
# 1  CP10CNSM  Coastal Pioneer MAB Central Surface Mooring  MFD37
#
#                             node_name    instrument   instrument_name  \
# 0       Near Surface Instrument Frame  04-DOSTAD000  Dissolved Oxygen
# 1  Seafloor Multi-Function Node (MFN)  04-DOSTAD000  Dissolved Oxygen
#
#                         refdes  \
# 0  CP10CNSM-RID27-04-DOSTAD000
# 1  CP10CNSM-MFD37-04-DOSTAD000
#
#                                                  url deployments
# 0  https://ooinet.oceanobservatories.org/api/m2m/...         [1]
# 1  https://ooinet.oceanobservatories.org/api/m2m/...         [1]

# %%
cnsm_datasets.iloc[1]["url"]
# Out:
# 'https://ooinet.oceanobservatories.org/api/m2m/12576/sensor/inv/CP10CNSM/MFD37/04-DOSTAD000'

# %% [markdown]
# You will still need to query the M2M API to get the available methods and data streams for the reference designator that you choose.

# %% [markdown]
# Now, we could go ahead and request data for the Coastal Pioneer Central Surface Mooring Dissolved Oxygen Sensor on the seafloor multifunction node by using the API Endpoint https://ooinet.oceanobservatories.org/api/m2m/12576/sensor/inv/CP10CNSM/MFD37/04-DOSTAD000. However, this request will return _all_ of the available data and _all_ of the parameters for the sensor, including a lot of engineering or unprocessed data.
#
# Instead, we can interrogate the OOI M2M system to get information on when the sensor has been deployed, what parameters are available on what data streams, and start to narrow our data request to only those parameters, time periods, and/or deployments that we may be interested in.

# %% [markdown]
# ---
# ## Deployment Information
# A deployment is defined as the span of time a mooring or instrument were deployed and then recovered. When we searched for the dissolved oxygen sensor on the Global Ocean Station Papa Flanking Mooring A, it returned a table which listed the available deployment numbers for each of the datasets. We can get much more detailed information on the deployments for a particular reference designator by requesting the deployment information from OOINet.
#
# We can start by using the deployment endpoint and reference designator to get a list of the available deployments for the reference designator:

# %%
refdes = "CP10CNSM-MFD37-04-DOSTAD000"
site, node, sensor = refdes.split("-", 2)

# %%
# First, we can request the deployment numbers for the given site-node-stream
print("API Endpoint: " + "/".join((URLS["deploy"], site, node, sensor)) + "\n")
print(get_api("/".join((URLS["deploy"], site, node, sensor))))
# Out:
# API Endpoint: https://ooinet.oceanobservatories.org/api/m2m/12587/events/deployment/inv/CP10CNSM/MFD37/04-DOSTAD000
#
# [1]

# %% [markdown]
# If we want more detailed information about a given deployment, we need to add in the deployment number:

# %%
# Returns asset and calibration information for deployment
deployment_number = "1"
data = get_api("/".join((URLS["deploy"], site, node, sensor, deployment_number)))
data
# Out:
# [{'@class': '.XDeployment',
#   'lastModifiedTimestamp': 1725584033449,
#   'dataSource': 'Load from [CP10CNSM_Deploy.xlsx]',
#   'eventName': 'CP10CNSM-MFD37-04-DOSTAD000',
#   'eventType': 'DEPLOYMENT',
#   'eventStartTime': 1712152620000,
#   'eventStopTime': None,
#   'notes': None,
#   'eventId': 10393,
#   'assetUid': None,
#   'deployCruiseInfo': {'@class': '.CruiseInfo',
#    'lastModifiedTimestamp': 1725583955574,
#    'dataSource': 'Load from [CruiseInformation.xlsx]',
#    'eventName': 'AR82',
#    'eventType': 'CRUISE_INFO',
#    'eventStartTime': 1711977600000,
#    'eventStopTime': 1713708120000,
#    'notes': None,
#    'eventId': 342,
#    'assetUid': None,
#    'uniqueCruiseIdentifier': 'AR82',
#    'shipName': 'Neil Armstrong',
#    'editPhase': 'OPERATIONAL',
#    'cruiseIdentifier': None,
#    'tense': 'UNKNOWN'},
#   'recoverCruiseInfo': None,
#   'deployedBy': None,
#   'recoveredBy': None,
#   'referenceDesignator': 'CP10CNSM-MFD37-04-DOSTAD000',
#   'deploymentNumber': 1,
#   'versionNumber': 1,
#   'inductiveId': None,
#   'waterDepth': 32.0,
#   'mooring': {'@class': '.XMooring',
#    'lastModifiedTimestamp': 1725583962494,
#    'dataSource': 'BulkLoad from [platform_bulk_load-AssetRecord.csv]',
#    'name': 'CP10CNSM-00001',
#    'uid': 'CGMCP-10CNSM-00001',
#    'assetType': 'Mooring',
#    'mobile': False,
#    'description': 'Coastal Pioneer MAB Central Surface Mooring',
#    'manufacturer': 'WHOI',
#    'modelNumber': 'CP10CNSM',
#    'serialNumber': 'CP10CNSM-00001',
#    'purchasePrice': None,
#    'purchaseDate': None,
#    'deliveryDate': None,
#    'depthRating': None,
#    'location': None,
#    'physicalInfo': {'length': -1.0,
#     'width': -1.0,
#     'height': -1.0,
#     'weight': -1.0},
#    'owner': 'Woods Hole Oceanographic Institution',
#    'ooiPropertyNumber': None,
#    'ooiPartNumber': None,
#    'ooiSerialNumber': None,
#    'deliveryOrderNumber': None,
#    'institutionPropertyNumber': None,
#    'institutionPurchaseOrderNumber': None,
#    'shelfLifeExpirationDate': None,
#    'firmwareVersion': None,
#    'softwareVersion': None,
#    'powerRequirements': None,
#    'notes': None,
#    'editPhase': 'OPERATIONAL',
#    'assetId': 866,
#    'events': [],
#    'remoteResources': []},
#   'node': None,
#   'sensor': {'@class': '.XInstrument',
#    'lastModifiedTimestamp': 1725583976057,
#    'dataSource': 'BulkLoad from [sensor_bulk_load-AssetRecord.csv]',
#    'name': '394',
#    'uid': 'CGINS-DOSTAD-00394',
#    'assetType': 'Sensor',
#    'mobile': False,
#    'description': 'Dissolved Oxygen Stable Response: DOSTA Series D',
#    'manufacturer': 'Aanderaa',
#    'modelNumber': 'Optode 4831',
#    'serialNumber': '394',
#    'purchasePrice': 5258.25,
#    'purchaseDate': 1405036800000,
#    'deliveryDate': 1405036800000,
#    'depthRating': None,
#    'location': None,
#    'physicalInfo': {'length': -1.0,
#     'width': -1.0,
#     'height': -1.0,
#     'weight': -1.0},
#    'owner': 'Woods Hole Oceanographic Institution',
#    'ooiPropertyNumber': None,
#    'ooiPartNumber': None,
#    'ooiSerialNumber': None,
#    'deliveryOrderNumber': None,
#    'institutionPropertyNumber': None,
#    'institutionPurchaseOrderNumber': None,
#    'shelfLifeExpirationDate': None,
#    'firmwareVersion': None,
#    'softwareVersion': None,
#    'powerRequirements': None,
#    'notes': None,
#    'editPhase': 'OPERATIONAL',
#    'assetId': 3995,
#    'events': [],
#    'remoteResources': [],
#    'calibration': [{'@class': '.XCalibration',
#      'name': 'CC_conc_coef',
#      'calData': [{'@class': '.XCalibrationData',
#        'lastModifiedTimestamp': 1725584319584,
#        'dataSource': 'CGINS-DOSTAD-00394__20140620_Cal_Info.xlsx',
#        'eventName': 'CC_conc_coef',
#        'eventType': 'CALIBRATION_DATA',
#        'eventStartTime': 1403222400000,
#        'eventStopTime': None,
#        'notes': None,
#        'eventId': 81709,
#        'assetUid': 'CGINS-DOSTAD-00394',
#        'comments': 'default',
#        'value': [0.0, 1.0],
#        'tense': 'UNKNOWN'},
#       {'@class': '.XCalibrationData',
#        'lastModifiedTimestamp': 1725584319620,
#        'dataSource': 'CGINS-DOSTAD-00394__20231126_Cal_Info.xlsx',
#        'eventName': 'CC_conc_coef',
#        'eventType': 'CALIBRATION_DATA',
#        'eventStartTime': 1700956800000,
#        'eventStopTime': None,
#        'notes': None,
#        'eventId': 81714,
#        'assetUid': 'CGINS-DOSTAD-00394',
#        'comments': '[offset, slope]; source_file DOSTA-D_Optode-4831_SN_394_Multipoint_Calibration_2023-11-26.pdf',
#        'value': [0.0, 1.0],
#        'tense': 'UNKNOWN'},
#       {'@class': '.XCalibrationData',
#        'lastModifiedTimestamp': 1725584319602,
#        'dataSource': 'CGINS-DOSTAD-00394__20170321_Cal_Info.xlsx',
#        'eventName': 'CC_conc_coef',
#        'eventType': 'CALIBRATION_DATA',
#        'eventStartTime': 1490054400000,
#        'eventStopTime': None,
#        'notes': None,
#        'eventId': 81712,
#        'assetUid': 'CGINS-DOSTAD-00394',
#        'comments': '[offset, slope]',
#        'value': [-2.162393, 1.063028],
#        'tense': 'UNKNOWN'}]},
#     {'@class': '.XCalibration',
#      'name': 'CC_csv',
#      'calData': [{'@class': '.XCalibrationData',
#        'lastModifiedTimestamp': 1725584319620,
#        'dataSource': 'CGINS-DOSTAD-00394__20231126_Cal_Info.xlsx',
#        'eventName': 'CC_csv',
#        'eventType': 'CALIBRATION_DATA',
#        'eventStartTime': 1700956800000,
#        'eventStopTime': None,
#        'notes': None,
#        'eventId': 81715,
#        'assetUid': 'CGINS-DOSTAD-00394',
#        'comments': None,
#        'value': [0.00259917,
#         0.000110874,
#         2.10957e-06,
#         160.512,
#         -0.212933,
#         -39.5175,
#         3.15948],
#        'tense': 'UNKNOWN'},
#       {'@class': '.XCalibrationData',
#        'lastModifiedTimestamp': 1725584319602,
#        'dataSource': 'CGINS-DOSTAD-00394__20170321_Cal_Info.xlsx',
#        'eventName': 'CC_csv',
#        'eventType': 'CALIBRATION_DATA',
#        'eventStartTime': 1490054400000,
#        'eventStopTime': None,
#        'notes': None,
#        'eventId': 81713,
#        'assetUid': 'CGINS-DOSTAD-00394',
#        'comments': None,
#        'value': [0.00284877,
#         0.000120979,
#         2.43655e-06,
#         230.03,
#         -0.323256,
#         -58.5685,
#         4.54455],
#        'tense': 'UNKNOWN'},
#       {'@class': '.XCalibrationData',
#        'lastModifiedTimestamp': 1725584319584,
#        'dataSource': 'CGINS-DOSTAD-00394__20140620_Cal_Info.xlsx',
#        'eventName': 'CC_csv',
#        'eventType': 'CALIBRATION_DATA',
#        'eventStartTime': 1403222400000,
#        'eventStopTime': None,
#        'notes': None,
#        'eventId': 81711,
#        'assetUid': 'CGINS-DOSTAD-00394',
#        'comments': None,
#        'value': [0.00284877,
#         0.000120979,
#         2.43655e-06,
#         230.03,
#         -0.323256,
#         -58.5685,
#         4.54455],
#        'tense': 'UNKNOWN'}]}]},
#   'location': {'latitude': 35.94988,
#    'longitude': -75.11943,
#    'depth': 31.0,
#    'orbitRadius': None,
#    'location': [-75.11943, 35.94988]},
#   'editPhase': 'OPERATIONAL',
#   'ingestInfo': [],
#   'tense': 'UNKNOWN'}]

# %% [markdown]
# This returns a json object with a dictionary that contains a lot of very, very detailed information. Depending on what you want, this has to be parsed out. Since we are interested in deployment information, lets
# parse that relevant info such as deployment start/end times, the unique ID of the instrument deployed, what cruise it was deployed on, etc:

# %%
deploymentInfo = pd.DataFrame()
for d in data: # If you requested more than one deployment
    deploymentDict = {
        "deploymentNumber": [d.get("deploymentNumber")],
        "referenceDesignator": [d.get("referenceDesignator")],
        "mooring": [d.get("mooring").get("description")],
        "sensor": [d.get("sensor").get("description")],
        "UID": [d.get("sensor").get("uid")],
        "deployDateTime": [convert_time(d.get("eventStartTime")).strftime("%Y-%m-%dT%H:%M:%SZ")],
        #"recoverDateTime": convert_time(d.get("eventStopTime")).strftime("%Y-%m-%dT%H:%M:%SZ"),
        "deployDateTime": [None],
        "deployCruise": [d.get("deployCruiseInfo").get("eventName")],
        #"recoverCruise": d.get("recoverCruiseInfo").get("eventName")
        "recoverCruise": [None], # Since its the first deployment, doesn't exist yet
    }
    df = pd.DataFrame(deploymentDict)
    deploymentInfo = pd.concat([deploymentInfo, df], ignore_index=True)
deploymentInfo
# Out:
#    deploymentNumber          referenceDesignator  \
# 0                 1  CP10CNSM-MFD37-04-DOSTAD000
#
#                                        mooring  \
# 0  Coastal Pioneer MAB Central Surface Mooring
#
#                                              sensor                 UID  \
# 0  Dissolved Oxygen Stable Response: DOSTA Series D  CGINS-DOSTAD-00394
#
#   deployDateTime deployCruise recoverCruise
# 0           None         AR82          None

# %% [markdown]
# The included function in the tutorial package ```get_deployments``` takes a reference designator, i.e. GP03FLMA-RIS01-02-DOSTAD000, parses it into the {site}/{node}/{sensor} information, and fetches all of the available info on the deployments for the given reference designator and returns it as a pandas dataframe.

# %%
deployments = get_deployments(refdes)
deployments
# Out:
#   deploymentNumber                 uid assetId  latitude longitude depth  \
# 0                1  CGINS-DOSTAD-00394    3995  35.94988 -75.11943  31.0
#
#           deployStart deployEnd deployCruise recoverCruise
# 0 2024-04-03 13:57:00      None         AR82          None

# %% [markdown]
# ---
# ## Vocab Information
# Additionally, if we are interested in more detailed information on the location that the reference designator is assigned to, we can request the vocab information for the given reference designator. The request returns a JSON object with details on the instrument such as the descriptive names for the reference designator location, the nominal depths, the manufacturer as well as the instrument model, etc. The vocab information includes some of the "**English_names**" info we requested when searching for datasets.

# %%
vocab_url = "/".join((URLS["vocab"], site, node, sensor))
print(vocab_url + "\n") 

vocab = get_api(vocab_url)
vocab
# Out:
# https://ooinet.oceanobservatories.org/api/m2m/12586/vocab/inv/CP10CNSM/MFD37/04-DOSTAD000
# [{'@class': '.VocabRecord',
#   'vocabId': 931,
#   'refdes': 'CP10CNSM-MFD37-04-DOSTAD000',
#   'instrument': 'Dissolved Oxygen',
#   'tocL1': 'Coastal Pioneer MAB',
#   'tocL2': 'Central Surface Mooring',
#   'tocL3': 'Seafloor Multi-Function Node (MFN)',
#   'manufacturer': 'Aanderaa',
#   'model': 'Optode 4831',
#   'mindepth': 29.0,
#   'maxdepth': 29.0}]

# %% [markdown]
# The included function ```get_vocab``` performs the request and reformats the JSON object into a pandas dataframe

# %%
vocab = get_vocab(refdes)
vocab
# Out:
#          @class  vocabId                       refdes        instrument  \
# 0  .VocabRecord      931  CP10CNSM-MFD37-04-DOSTAD000  Dissolved Oxygen
#
#                  tocL1                    tocL2  \
# 0  Coastal Pioneer MAB  Central Surface Mooring
#
#                                 tocL3 manufacturer        model  mindepth  \
# 0  Seafloor Multi-Function Node (MFN)     Aanderaa  Optode 4831      29.0
#
#    maxdepth
# 0      29.0

# %% [markdown]
# ---
# ## Calibration Information
# We can also request the calibration information for a given reference designator. Since individual instruments are swapped during each mooring deployment & recovery, the calibration coefficients for a reference designator are different for each deployment. The way OOI operates is that it loads all the available calibration coefficients for a given reference designator. Then, for each deployment, it finds the calibration coefficients with the most recent calibration date which most closely _precedes_ the start of the deployment. The result is a table, sorted by deployment number for a reference designator, with the uid of the specific instrument, its calibration coefficients, when the instrument was calibrated, and the source of the calibration coefficients.

# %%
cal_url = URLS["cal"] + "?refdes=" + refdes
print(cal_url + "\n")

cal_data = get_api(cal_url)
cal_data
# Out:
# https://ooinet.oceanobservatories.org/api/m2m/12587/asset/cal?refdes=CP10CNSM-MFD37-04-DOSTAD000
# [{'@class': '.XDeployment',
#   'lastModifiedTimestamp': 1725584033449,
#   'dataSource': 'Load from [CP10CNSM_Deploy.xlsx]',
#   'eventName': 'CP10CNSM-MFD37-04-DOSTAD000',
#   'eventType': 'DEPLOYMENT',
#   'eventStartTime': 1712152620000,
#   'eventStopTime': None,
#   'notes': None,
#   'eventId': 10393,
#   'assetUid': None,
#   'deployCruiseInfo': {'@class': '.CruiseInfo',
#    'lastModifiedTimestamp': 1725583955574,
#    'dataSource': 'Load from [CruiseInformation.xlsx]',
#    'eventName': 'AR82',
#    'eventType': 'CRUISE_INFO',
#    'eventStartTime': 1711977600000,
#    'eventStopTime': 1713708120000,
#    'notes': None,
#    'eventId': 342,
#    'assetUid': None,
#    'uniqueCruiseIdentifier': 'AR82',
#    'shipName': 'Neil Armstrong',
#    'editPhase': 'OPERATIONAL',
#    'cruiseIdentifier': None,
#    'tense': 'UNKNOWN'},
#   'recoverCruiseInfo': None,
#   'deployedBy': None,
#   'recoveredBy': None,
#   'referenceDesignator': 'CP10CNSM-MFD37-04-DOSTAD000',
#   'deploymentNumber': 1,
#   'versionNumber': 1,
#   'inductiveId': None,
#   'waterDepth': 32.0,
#   'mooring': {'@class': '.XMooring',
#    'lastModifiedTimestamp': 1725583962494,
#    'dataSource': 'BulkLoad from [platform_bulk_load-AssetRecord.csv]',
#    'name': 'CP10CNSM-00001',
#    'uid': 'CGMCP-10CNSM-00001',
#    'assetType': 'Mooring',
#    'mobile': False,
#    'description': 'Coastal Pioneer MAB Central Surface Mooring',
#    'manufacturer': 'WHOI',
#    'modelNumber': 'CP10CNSM',
#    'serialNumber': 'CP10CNSM-00001',
#    'purchasePrice': None,
#    'purchaseDate': None,
#    'deliveryDate': None,
#    'depthRating': None,
#    'location': None,
#    'physicalInfo': {'length': -1.0,
#     'width': -1.0,
#     'height': -1.0,
#     'weight': -1.0},
#    'owner': 'Woods Hole Oceanographic Institution',
#    'ooiPropertyNumber': None,
#    'ooiPartNumber': None,
#    'ooiSerialNumber': None,
#    'deliveryOrderNumber': None,
#    'institutionPropertyNumber': None,
#    'institutionPurchaseOrderNumber': None,
#    'shelfLifeExpirationDate': None,
#    'firmwareVersion': None,
#    'softwareVersion': None,
#    'powerRequirements': None,
#    'notes': None,
#    'editPhase': 'OPERATIONAL',
#    'assetId': 866,
#    'events': [],
#    'remoteResources': []},
#   'node': None,
#   'sensor': {'@class': '.XInstrument',
#    'lastModifiedTimestamp': 1725583976057,
#    'dataSource': 'BulkLoad from [sensor_bulk_load-AssetRecord.csv]',
#    'name': '394',
#    'uid': 'CGINS-DOSTAD-00394',
#    'assetType': 'Sensor',
#    'mobile': False,
#    'description': 'Dissolved Oxygen Stable Response: DOSTA Series D',
#    'manufacturer': 'Aanderaa',
#    'modelNumber': 'Optode 4831',
#    'serialNumber': '394',
#    'purchasePrice': 5258.25,
#    'purchaseDate': 1405036800000,
#    'deliveryDate': 1405036800000,
#    'depthRating': None,
#    'location': None,
#    'physicalInfo': {'length': -1.0,
#     'width': -1.0,
#     'height': -1.0,
#     'weight': -1.0},
#    'owner': 'Woods Hole Oceanographic Institution',
#    'ooiPropertyNumber': None,
#    'ooiPartNumber': None,
#    'ooiSerialNumber': None,
#    'deliveryOrderNumber': None,
#    'institutionPropertyNumber': None,
#    'institutionPurchaseOrderNumber': None,
#    'shelfLifeExpirationDate': None,
#    'firmwareVersion': None,
#    'softwareVersion': None,
#    'powerRequirements': None,
#    'notes': None,
#    'editPhase': 'OPERATIONAL',
#    'assetId': 3995,
#    'events': [],
#    'remoteResources': [],
#    'calibration': [{'@class': '.XCalibration',
#      'name': 'CC_conc_coef',
#      'calData': [{'@class': '.XCalibrationData',
#        'lastModifiedTimestamp': 1725584319584,
#        'dataSource': 'CGINS-DOSTAD-00394__20140620_Cal_Info.xlsx',
#        'eventName': 'CC_conc_coef',
#        'eventType': 'CALIBRATION_DATA',
#        'eventStartTime': 1403222400000,
#        'eventStopTime': None,
#        'notes': None,
#        'eventId': 81709,
#        'assetUid': 'CGINS-DOSTAD-00394',
#        'comments': 'default',
#        'value': [0.0, 1.0],
#        'tense': 'UNKNOWN'},
#       {'@class': '.XCalibrationData',
#        'lastModifiedTimestamp': 1725584319620,
#        'dataSource': 'CGINS-DOSTAD-00394__20231126_Cal_Info.xlsx',
#        'eventName': 'CC_conc_coef',
#        'eventType': 'CALIBRATION_DATA',
#        'eventStartTime': 1700956800000,
#        'eventStopTime': None,
#        'notes': None,
#        'eventId': 81714,
#        'assetUid': 'CGINS-DOSTAD-00394',
#        'comments': '[offset, slope]; source_file DOSTA-D_Optode-4831_SN_394_Multipoint_Calibration_2023-11-26.pdf',
#        'value': [0.0, 1.0],
#        'tense': 'UNKNOWN'},
#       {'@class': '.XCalibrationData',
#        'lastModifiedTimestamp': 1725584319602,
#        'dataSource': 'CGINS-DOSTAD-00394__20170321_Cal_Info.xlsx',
#        'eventName': 'CC_conc_coef',
#        'eventType': 'CALIBRATION_DATA',
#        'eventStartTime': 1490054400000,
#        'eventStopTime': None,
#        'notes': None,
#        'eventId': 81712,
#        'assetUid': 'CGINS-DOSTAD-00394',
#        'comments': '[offset, slope]',
#        'value': [-2.162393, 1.063028],
#        'tense': 'UNKNOWN'}]},
#     {'@class': '.XCalibration',
#      'name': 'CC_csv',
#      'calData': [{'@class': '.XCalibrationData',
#        'lastModifiedTimestamp': 1725584319620,
#        'dataSource': 'CGINS-DOSTAD-00394__20231126_Cal_Info.xlsx',
#        'eventName': 'CC_csv',
#        'eventType': 'CALIBRATION_DATA',
#        'eventStartTime': 1700956800000,
#        'eventStopTime': None,
#        'notes': None,
#        'eventId': 81715,
#        'assetUid': 'CGINS-DOSTAD-00394',
#        'comments': None,
#        'value': [0.00259917,
#         0.000110874,
#         2.10957e-06,
#         160.512,
#         -0.212933,
#         -39.5175,
#         3.15948],
#        'tense': 'UNKNOWN'},
#       {'@class': '.XCalibrationData',
#        'lastModifiedTimestamp': 1725584319584,
#        'dataSource': 'CGINS-DOSTAD-00394__20140620_Cal_Info.xlsx',
#        'eventName': 'CC_csv',
#        'eventType': 'CALIBRATION_DATA',
#        'eventStartTime': 1403222400000,
#        'eventStopTime': None,
#        'notes': None,
#        'eventId': 81711,
#        'assetUid': 'CGINS-DOSTAD-00394',
#        'comments': None,
#        'value': [0.00284877,
#         0.000120979,
#         2.43655e-06,
#         230.03,
#         -0.323256,
#         -58.5685,
#         4.54455],
#        'tense': 'UNKNOWN'},
#       {'@class': '.XCalibrationData',
#        'lastModifiedTimestamp': 1725584319602,
#        'dataSource': 'CGINS-DOSTAD-00394__20170321_Cal_Info.xlsx',
#        'eventName': 'CC_csv',
#        'eventType': 'CALIBRATION_DATA',
#        'eventStartTime': 1490054400000,
#        'eventStopTime': None,
#        'notes': None,
#        'eventId': 81713,
#        'assetUid': 'CGINS-DOSTAD-00394',
#        'comments': None,
#        'value': [0.00284877,
#         0.000120979,
#         2.43655e-06,
#         230.03,
#         -0.323256,
#         -58.5685,
#         4.54455],
#        'tense': 'UNKNOWN'}]}]},
#   'location': {'latitude': 35.94988,
#    'longitude': -75.11943,
#    'depth': 31.0,
#    'orbitRadius': None,
#    'location': [-75.11943, 35.94988]},
#   'editPhase': 'OPERATIONAL',
#   'ingestInfo': [],
#   'tense': 'UNKNOWN'}]

# %% [markdown]
# We can see that the returned JSON object has multiple entries. Since individual instruments are swapped during each mooring deployment & recovery, the calibration coefficients for a reference designator are different for each deployment. The way OOI operates is that it loads all the available calibration coefficients for a given reference designator. Then, for each deployment, it finds the calibration coefficients with the most recent calibration date which most closely _precedes_ the start of the deployment, and applies those for the given deployment.
#
# However, when going through each entry, you'll notice that each deployment entry has all of the calibrations in the system entered for that given instrument UID. This makes parsing it very confusing. A better approach is to limit your request to a single deployment or even a single day by adding in **beginDT** and **endDT** to the request.

# %%
# Limit the request to Deployment 6: summer of 2018 to summer of 2019
beginDT = "2024-09-11T22:54:00.000Z"
endDT = "2024-09-11T22:54:00.000Z"

# 
cal_url = URLS["cal"] + "?refdes=" + refdes + "&beginDT=" + beginDT + "&endDT=" + endDT
print("API Endpoint: " + cal_url + "\n")

cal_data = get_api(cal_url)
cal_data
# Out:
# API Endpoint: https://ooinet.oceanobservatories.org/api/m2m/12587/asset/cal?refdes=CP10CNSM-MFD37-04-DOSTAD000&beginDT=2024-09-11T22:54:00.000Z&endDT=2024-09-11T22:54:00.000Z
# [{'@class': '.XDeployment',
#   'lastModifiedTimestamp': 1725584033449,
#   'dataSource': 'Load from [CP10CNSM_Deploy.xlsx]',
#   'eventName': 'CP10CNSM-MFD37-04-DOSTAD000',
#   'eventType': 'DEPLOYMENT',
#   'eventStartTime': 1712152620000,
#   'eventStopTime': None,
#   'notes': None,
#   'eventId': 10393,
#   'assetUid': None,
#   'deployCruiseInfo': {'@class': '.CruiseInfo',
#    'lastModifiedTimestamp': 1725583955574,
#    'dataSource': 'Load from [CruiseInformation.xlsx]',
#    'eventName': 'AR82',
#    'eventType': 'CRUISE_INFO',
#    'eventStartTime': 1711977600000,
#    'eventStopTime': 1713708120000,
#    'notes': None,
#    'eventId': 342,
#    'assetUid': None,
#    'uniqueCruiseIdentifier': 'AR82',
#    'shipName': 'Neil Armstrong',
#    'editPhase': 'OPERATIONAL',
#    'cruiseIdentifier': None,
#    'tense': 'UNKNOWN'},
#   'recoverCruiseInfo': None,
#   'deployedBy': None,
#   'recoveredBy': None,
#   'referenceDesignator': 'CP10CNSM-MFD37-04-DOSTAD000',
#   'deploymentNumber': 1,
#   'versionNumber': 1,
#   'inductiveId': None,
#   'waterDepth': 32.0,
#   'mooring': {'@class': '.XMooring',
#    'lastModifiedTimestamp': 1725583962494,
#    'dataSource': 'BulkLoad from [platform_bulk_load-AssetRecord.csv]',
#    'name': 'CP10CNSM-00001',
#    'uid': 'CGMCP-10CNSM-00001',
#    'assetType': 'Mooring',
#    'mobile': False,
#    'description': 'Coastal Pioneer MAB Central Surface Mooring',
#    'manufacturer': 'WHOI',
#    'modelNumber': 'CP10CNSM',
#    'serialNumber': 'CP10CNSM-00001',
#    'purchasePrice': None,
#    'purchaseDate': None,
#    'deliveryDate': None,
#    'depthRating': None,
#    'location': None,
#    'physicalInfo': {'length': -1.0,
#     'width': -1.0,
#     'height': -1.0,
#     'weight': -1.0},
#    'owner': 'Woods Hole Oceanographic Institution',
#    'ooiPropertyNumber': None,
#    'ooiPartNumber': None,
#    'ooiSerialNumber': None,
#    'deliveryOrderNumber': None,
#    'institutionPropertyNumber': None,
#    'institutionPurchaseOrderNumber': None,
#    'shelfLifeExpirationDate': None,
#    'firmwareVersion': None,
#    'softwareVersion': None,
#    'powerRequirements': None,
#    'notes': None,
#    'editPhase': 'OPERATIONAL',
#    'assetId': 866,
#    'events': [],
#    'remoteResources': []},
#   'node': None,
#   'sensor': {'@class': '.XInstrument',
#    'lastModifiedTimestamp': 1725583976057,
#    'dataSource': 'BulkLoad from [sensor_bulk_load-AssetRecord.csv]',
#    'name': '394',
#    'uid': 'CGINS-DOSTAD-00394',
#    'assetType': 'Sensor',
#    'mobile': False,
#    'description': 'Dissolved Oxygen Stable Response: DOSTA Series D',
#    'manufacturer': 'Aanderaa',
#    'modelNumber': 'Optode 4831',
#    'serialNumber': '394',
#    'purchasePrice': 5258.25,
#    'purchaseDate': 1405036800000,
#    'deliveryDate': 1405036800000,
#    'depthRating': None,
#    'location': None,
#    'physicalInfo': {'length': -1.0,
#     'width': -1.0,
#     'height': -1.0,
#     'weight': -1.0},
#    'owner': 'Woods Hole Oceanographic Institution',
#    'ooiPropertyNumber': None,
#    'ooiPartNumber': None,
#    'ooiSerialNumber': None,
#    'deliveryOrderNumber': None,
#    'institutionPropertyNumber': None,
#    'institutionPurchaseOrderNumber': None,
#    'shelfLifeExpirationDate': None,
#    'firmwareVersion': None,
#    'softwareVersion': None,
#    'powerRequirements': None,
#    'notes': None,
#    'editPhase': 'OPERATIONAL',
#    'assetId': 3995,
#    'events': [],
#    'remoteResources': [],
#    'calibration': [{'@class': '.XCalibration',
#      'name': 'CC_conc_coef',
#      'calData': [{'@class': '.XCalibrationData',
#        'lastModifiedTimestamp': 1725584319620,
#        'dataSource': 'CGINS-DOSTAD-00394__20231126_Cal_Info.xlsx',
#        'eventName': 'CC_conc_coef',
#        'eventType': 'CALIBRATION_DATA',
#        'eventStartTime': 1700956800000,
#        'eventStopTime': None,
#        'notes': None,
#        'eventId': 81714,
#        'assetUid': 'CGINS-DOSTAD-00394',
#        'comments': '[offset, slope]; source_file DOSTA-D_Optode-4831_SN_394_Multipoint_Calibration_2023-11-26.pdf',
#        'value': [0.0, 1.0],
#        'tense': 'UNKNOWN'}]},
#     {'@class': '.XCalibration',
#      'name': 'CC_csv',
#      'calData': [{'@class': '.XCalibrationData',
#        'lastModifiedTimestamp': 1725584319620,
#        'dataSource': 'CGINS-DOSTAD-00394__20231126_Cal_Info.xlsx',
#        'eventName': 'CC_csv',
#        'eventType': 'CALIBRATION_DATA',
#        'eventStartTime': 1700956800000,
#        'eventStopTime': None,
#        'notes': None,
#        'eventId': 81715,
#        'assetUid': 'CGINS-DOSTAD-00394',
#        'comments': None,
#        'value': [0.00259917,
#         0.000110874,
#         2.10957e-06,
#         160.512,
#         -0.212933,
#         -39.5175,
#         3.15948],
#        'tense': 'UNKNOWN'}]}]},
#   'location': {'latitude': 35.94988,
#    'longitude': -75.11943,
#    'depth': 31.0,
#    'orbitRadius': None,
#    'location': [-75.11943, 35.94988]},
#   'editPhase': 'OPERATIONAL',
#   'ingestInfo': [],
#   'tense': 'UNKNOWN'}]

# %% [markdown]
# Now we can parse the JSON file to get the relevant calibration information for the TURBD instrument deployed at Coastal Pioneer MAB Central Surface Mooring:

# %%
calibrations = pd.DataFrame()
for c in cal_data:
    deploymentNumber = c.get("deploymentNumber")
    uid = c.get("sensor").get("uid")
    for cc in c.get("sensor").get("calibration"):
        for ccc in cc.get("calData"):
            name = ccc.get("eventName")
            value = ccc.get("value")
            source = ccc.get("dataSource")
            # Update the calibration data frame
            caldf = pd.DataFrame({
                "deploymentNumber": [deploymentNumber],
                "uid": [uid],
                "calCoef": [name],
                "value": [value],
                "calFile": [source],
            })
            calibrations = pd.concat([calibrations, caldf], ignore_index=True)
            
calibrations
# Out:
#    deploymentNumber                 uid       calCoef  \
# 0                 1  CGINS-DOSTAD-00394  CC_conc_coef
# 1                 1  CGINS-DOSTAD-00394        CC_csv
#
#                                                value  \
# 0                                         [0.0, 1.0]
# 1  [0.00259917, 0.000110874, 2.10957e-06, 160.512...
#
#                                       calFile
# 0  CGINS-DOSTAD-00394__20231126_Cal_Info.xlsx
# 1  CGINS-DOSTAD-00394__20231126_Cal_Info.xlsx

# %% [markdown]
# The function ```get_calibrations``` included in this tutorial drastically simplifies the requests. However, it does need the **deployment** information fetched using the ```get_deployments``` function. What is nice about the function is that it will return the calibrations applicable for each deployment and just that deployment.

# %%
calibrations = get_calibrations_by_refdes(refdes, deployments)
calibrations
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 calibrations = get_calibrations_by_refdes(refdes, deployments)
#       2 calibrations
#
# File ~/code/ooi-data-explorations/meetings/NE-Pacific-Community-Workshop/Tutorial/tutorial/../src/pyOOI/M2M.py:306, in get_calibrations_by_refdes(refdes, deployments)
#     303     calInfo = get_api(URLS["cal"], params)
#     305     # Reformat the data
# --> 306     calDataFrame =  reformat_calInfo(calInfo, deployNum, uid)
#     308     cals.append(calDataFrame)
#     310 # Append individual calibrations into a single dataframe
#
# File ~/code/ooi-data-explorations/meetings/NE-Pacific-Community-Workshop/Tutorial/tutorial/../src/pyOOI/M2M.py:249, in reformat_calInfo(calInfo, deployNum, uid)
#     247 for cal in calInfo["calibration"]:
#     248     for calData in cal["calData"]:
# --> 249         df = pd.DataFrame({
#     250             "deploymentNumber": [int(deployNum)],
#     251             "uid": [uid],
#     252             "calCoef": list(calData["eventName"]),
#     253             "value": list(calData["value"]),
#     254             "calFile": list(calData["dataSource"])
#     255         })
#     256         calDataFrame = pd.concat([calDataFrame, df], ignore_index=True)
#     257 return calDataFrame
#
# File ~/.conda/envs/ooi/lib/python3.10/site-packages/pandas/core/frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File ~/.conda/envs/ooi/lib/python3.10/site-packages/pandas/core/internals/construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/.conda/envs/ooi/lib/python3.10/site-packages/pandas/core/internals/construction.py:115, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112 if verify_integrity:
#     113     # figure out the index, if necessary
#     114     if index is None:
# --> 115         index = _extract_index(arrays)
#     116     else:
#     117         index = ensure_index(index)
#
# File ~/.conda/envs/ooi/lib/python3.10/site-packages/pandas/core/internals/construction.py:655, in _extract_index(data)
#     653 lengths = list(set(raw_lengths))
#     654 if len(lengths) > 1:
# --> 655     raise ValueError("All arrays must be of the same length")
#     657 if have_dicts:
#     658     raise ValueError(
#     659         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     660     )
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# It is much easier to query for calibration data by the UID, or unique ID, for an instrument. For example, if we are looking at the oxygen optode deployed for Deployment 6, it has a UID of CGINS-DOSTAD-00228. We can request the calibration coefficients for that particular instrument.

# %%
# Set up the calibration url and arguments to pass to the request
uid = "CGINS-DOSTAD-00228" # This is unique to each instrument
cal_url = URLS["cal"] + "?uid=" + uid
print("API Endpoint: " + cal_url)

# Make the request
calInfo = get_api(cal_url)

# Put the data into a pandas dataframe, sorted by calibration date and coefficient name
columns = ["uid", "calCoef", "calDate", "value", "calFile"]
instrumentCals = pd.DataFrame(columns=columns)
for c in calInfo["calibration"]:
    for cc in c["calData"]:
        # Grab the unique data
        uid = cc["assetUid"]
        calCoef = cc["eventName"]
        calDate = convert_time(cc["eventStartTime"])
        value = cc["value"]
        calFile = cc["dataSource"]
        # Create a dataframe
        df = pd.DataFrame({
            "uid": uid,
            "calCoef": calCoef,
            "calDate": calDate,
            "value": value,
            "calFile": calFile
        })
        instrumentCals = pd.concat([instrumentCals, df], ignore_index=True)
GINS-DOSTAD-00228__20130804_Cal_Info.xlsx
# 1   CGINS-DOSTAD-00228__20130804_Cal_Info.xlsx
# 8   CGINS-DOSTAD-00228__20130804_Cal_Info.xlsx
# 9   CGINS-DOSTAD-00228__20130804_Cal_Info.xlsx
# 10  CGINS-DOSTAD-00228__20130804_Cal_Info.xlsx
# 11  CGINS-DOSTAD-00228__20130804_Cal_Info.xlsx
# 12  CGINS-DOSTAD-00228__20130804_Cal_Info.xlsx
# 13  CGINS-DOSTAD-00228__20130804_Cal_Info.xlsx
# 14  CGINS-DOSTAD-00228__20130804_Cal_Info.xlsx
# 2   CGINS-DOSTAD-00228__20160226_Cal_Info.xlsx
# 3   CGINS-DOSTAD-00228__20160226_Cal_Info.xlsx
# 22  CGINS-DOSTAD-00228__20160226_Cal_Info.xlsx
# 23  CGINS-DOSTAD-00228__20160226_Cal_Info.xlsx
# 24  CGINS-DOSTAD-00228__20160226_Cal_Info.xlsx
# 25  CGINS-DOSTAD-00228__20160226_Cal_Info.xlsx
# 26  CGINS-DOSTAD-00228__20160226_Cal_Info.xlsx
# 27  CGINS-DOSTAD-00228__20160226_Cal_Info.xlsx
# 28  CGINS-DOSTAD-00228__20160226_Cal_Info.xlsx
# 6   CGINS-DOSTAD-00228__20170918_Cal_Info.xlsx
# 7   CGINS-DOSTAD-00228__20170918_Cal_Info.xlsx
# 29  CGINS-DOSTAD-00228__20170918_Cal_Info.xlsx
# 30  CGINS-DOSTAD-00228__20170918_Cal_Info.xlsx
# 31  CGINS-DOSTAD-00228__20170918_Cal_Info.xlsx
# 32  CGINS-DOSTAD-00228__20170918_Cal_Info.xlsx
# 33  CGINS-DOSTAD-00228__20170918_Cal_Info.xlsx
# 34  CGINS-DOSTAD-00228__20170918_Cal_Info.xlsx
# 35  CGINS-DOSTAD-00228__20170918_Cal_Info.xlsx
# 4   CGINS-DOSTAD-00228__20231126_Cal_Info.xlsx
# 5   CGINS-DOSTAD-00228__20231126_Cal_Info.xlsx
# 15  CGINS-DOSTAD-00228__20231126_Cal_Info.xlsx
# 16  CGINS-DOSTAD-00228__20231126_Cal_Info.xlsx
# 17  CGINS-DOSTAD-00228__20231126_Cal_Info.xlsx
# 18  CGINS-DOSTAD-00228__20231126_Cal_Info.xlsx
# 19  CGINS-DOSTAD-00228__20231126_Cal_Info.xlsx
# 20  CGINS-DOSTAD-00228__20231126_Cal_Info.xlsx
# 21  CGINS-DOSTAD-00228__20231126_Cal_Info.xlsx

# %% [markdown]
# ---
# ## Metadata
# Next, we can query OOINet for the metadata associated with the selected reference designator. The metadata contains such valuable information such as the available **methods** and **streams** (which are required to download the data), the **particleKeys** (the data variable names), and the associated **units**.

# %%
metadata = get_metadata(refdes)
metadata
# Out:
#       pdId                     particleKey    type     shape  \
# 0      PD7                            time  DOUBLE    SCALAR
# 1     PD10                  port_timestamp  DOUBLE    SCALAR
# 2     PD11                driver_timestamp  DOUBLE    SCALAR
# 3     PD12              internal_timestamp  DOUBLE    SCALAR
# 4     PD14                dissolved_oxygen   FLOAT  FUNCTION
# 5     PD16             preferred_timestamp  STRING    SCALAR
# 6    PD312                   serial_number  STRING    SCALAR
# 7    PD863             ingestion_timestamp  DOUBLE    SCALAR
# 8    PD940  estimated_oxygen_concentration   FLOAT    SCALAR
# 9    PD941     estimated_oxygen_saturation   FLOAT    SCALAR
# 10   PD942              optode_temperature   FLOAT    SCALAR
# 11   PD943                calibrated_phase   FLOAT    SCALAR
# 12   PD944          temp_compensated_phase   FLOAT    SCALAR
# 13   PD945                      blue_phase   FLOAT    SCALAR
# 14   PD946                       red_phase   FLOAT    SCALAR
# 15   PD947                  blue_amplitude   FLOAT    SCALAR
# 16   PD948                   red_amplitude   FLOAT    SCALAR
# 17   PD949                 raw_temperature   FLOAT    SCALAR
# 18  PD1005                  product_number  USHORT    SCALAR
# 19  PD2605        dcl_controller_timestamp  STRING    SCALAR
# 20  PD2843     dosta_abcdjm_cspp_tc_oxygen   FLOAT  FUNCTION
#
#                        units fillValue                       stream  unsigned  \
# 0   seconds since 1900-01-01  -9999999  dosta_abcdjm_dcl_instrument     False
# 1   seconds since 1900-01-01  -9999999  dosta_abcdjm_dcl_instrument     False
# 2   seconds since 1900-01-01  -9999999  dosta_abcdjm_dcl_instrument     False
# 3   seconds since 1900-01-01  -9999999  dosta_abcdjm_dcl_instrument     False
# 4                  umol kg-1  -9999999  dosta_abcdjm_dcl_instrument     False
# 5                       None     empty  dosta_abcdjm_dcl_instrument     False
# 6                          1     empty  dosta_abcdjm_dcl_instrument     False
# 7   seconds since 1900-01-01     -9999  dosta_abcdjm_dcl_instrument     False
# 8                   umol L-1  -9999999  dosta_abcdjm_dcl_instrument     False
# 9                    percent  -9999999  dosta_abcdjm_dcl_instrument     False
# 10           degrees_Celsius  -9999999  dosta_abcdjm_dcl_instrument     False
# 11                   degrees  -9999999  dosta_abcdjm_dcl_instrument     False
# 12                   degrees  -9999999  dosta_abcdjm_dcl_instrument     False
# 13                   degrees  -9999999  dosta_abcdjm_dcl_instrument     False
# 14                   degrees  -9999999  dosta_abcdjm_dcl_instrument     False
# 15                        mV  -9999999  dosta_abcdjm_dcl_instrument     False
# 16                        mV  -9999999  dosta_abcdjm_dcl_instrument     False
# 17                        mV  -9999999  dosta_abcdjm_dcl_instrument     False
# 18                         1         0  dosta_abcdjm_dcl_instrument      True
# 19                      None     empty  dosta_abcdjm_dcl_instrument     False
# 20                  umol L-1  -9999999  dosta_abcdjm_dcl_instrument     False
#
#          method   count                 beginTime                   endTime  \
# 0   telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 1   telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 2   telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 3   telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 4   telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 5   telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 6   telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 7   telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 8   telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 9   telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 10  telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 11  telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 12  telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 13  telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 14  telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 15  telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 16  telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 17  telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 18  telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 19  telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 20  telemetered  110090  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
#
#                          refdes
# 0   CP10CNSM-MFD37-04-DOSTAD000
# 1   CP10CNSM-MFD37-04-DOSTAD000
# 2   CP10CNSM-MFD37-04-DOSTAD000
# 3   CP10CNSM-MFD37-04-DOSTAD000
# 4   CP10CNSM-MFD37-04-DOSTAD000
# 5   CP10CNSM-MFD37-04-DOSTAD000
# 6   CP10CNSM-MFD37-04-DOSTAD000
# 7   CP10CNSM-MFD37-04-DOSTAD000
# 8   CP10CNSM-MFD37-04-DOSTAD000
# 9   CP10CNSM-MFD37-04-DOSTAD000
# 10  CP10CNSM-MFD37-04-DOSTAD000
# 11  CP10CNSM-MFD37-04-DOSTAD000
# 12  CP10CNSM-MFD37-04-DOSTAD000
# 13  CP10CNSM-MFD37-04-DOSTAD000
# 14  CP10CNSM-MFD37-04-DOSTAD000
# 15  CP10CNSM-MFD37-04-DOSTAD000
# 16  CP10CNSM-MFD37-04-DOSTAD000
# 17  CP10CNSM-MFD37-04-DOSTAD000
# 18  CP10CNSM-MFD37-04-DOSTAD000
# 19  CP10CNSM-MFD37-04-DOSTAD000
# 20  CP10CNSM-MFD37-04-DOSTAD000

# %% [markdown]
# Now, there are a lot of different variables returned in the metadata for the Oxygen sensor. Unless we want to reprocess the raw data ourselves, we really just want the scientifically relevant parameters. But which ones are those?
#
# Level 1, or L1 Data Products, are derived from L0 data, and provide data that has been calibrated using vendor-provided values or values derived from pre-deployment procedures, and that is in scientific units.
#
# Example: Data from Aanderaa oxygen (DOSTA) sensors are converted from the L0 data  (DCONCS_L0) to the L1 dissolved oxygen concentrations data product (DCONCS_L1) internally using the manufacturer’s conversion factors. While this is done onboard of the oxygen optode, the L0 products, such as the amplitude, phase, etc are available if desired.
#
# Level 2, or L2 Data Products are derived quantities created via an algorithm that draws on multiple L1 Data Products. L2 data products may be based on data from the same or a combination of separate instruments.
#
# Example: Level 1 temperature (TEMPWAT_L1) and salinity (PRACSAL_L1) data products from the colocated CTD are used to produce a temperature and salinity corrected Level 2 dissolved oxygen concentration data product (DOXYGEN_L2).
#
# **We recommend that end users work with Level 2 Data Products for analysis**, and use Level 0 and Level 1 products only in cases where the end user has a specific reason requiring these earlier-stage data products for their own data processing needs.
#
# We can query for the relevant data product level from the "Preload Database" using the **pdId** field from the returned metadata. One note of caution: the data levels for some variables such as **time** are set as **None** even though time is a fundamental parameter.

# %%
# Lets query "time" for its data level
preload_url = URLS["preload"] + "/" + "14"
print("API Endpoint: " + preload_url)

get_api(preload_url)
# Out:
# API Endpoint: https://ooinet.oceanobservatories.org/api/m2m/12575/parameter/14
# {'name': 'dissolved_oxygen',
#  'display_name': 'DO from Onboard Calculation - Corrected',
#  'netcdf_name': 'dissolved_oxygen',
#  'standard_name': 'moles_of_oxygen_per_unit_mass_in_sea_water',
#  'description': 'Dissolved Oxygen (DO) concentration from the Stable Response DO Instrument is a measure of the concentration of gaseous oxygen mixed in seawater. This data product is corrected for salinity, temperature, and pressure.',
#  'id': 14,
#  'data_product_identifier': 'DOXYGEN_L2',
#  'precision': 4,
#  'fill_value': {'value': '-9999999'},
#  'unit': {'value': 'umol kg-1'},
#  'data_level': 2,
#  'code_set': None,
#  'value_encoding': {'value': 'float32'},
#  'parameter_type': {'value': 'function'},
#  'parameter_function': {'id': 61,
#   'name': 'do2_salinity_correction',
#   'function_type': {'value': 'PythonFunction'},
#   'function': 'do2_salinity_correction',
#   'owner': 'ion_functions.data.do2_functions',
#   'description': 'Salinity and pressure correction to dissolved oxygen producing L2 DOCONCS',
#   'qc_flag': None},
#  'data_product_type': {'value': 'Science Data'},
#  'dimensions': [],
#  'parameter_function_map': '{"DO": "dpi_DOCONCS_L1", "SP": ["dpi_PRACSAL_L2", "dpi_SALSURF_L2"], "lon": "CC_lon", "P": ["PD2606", "dpi_PRESWAT_L1", "PD17"], "T": ["dpi_TEMPWAT_L1", "dpi_TEMPSRF_L1"], "lat": "CC_lat"}',
#  'visible': True}

# %%
# Query the dissolved oxygen
preload_url = URLS["preload"] + "/" + "7"
print("API Endpoint: " + preload_url)

get_api(preload_url)
# Out:
# API Endpoint: https://ooinet.oceanobservatories.org/api/m2m/12575/parameter/7
# {'name': 'time',
#  'display_name': 'Time, UTC',
#  'netcdf_name': 'time',
#  'standard_name': 'time',
#  'description': 'Time, UTC',
#  'id': 7,
#  'data_product_identifier': None,
#  'precision': None,
#  'fill_value': {'value': '-9999999'},
#  'unit': {'value': 'seconds since 1900-01-01'},
#  'data_level': None,
#  'code_set': None,
#  'value_encoding': {'value': 'float64'},
#  'parameter_type': {'value': 'quantity'},
#  'parameter_function': None,
#  'data_product_type': None,
#  'dimensions': [],
#  'parameter_function_map': None,
#  'visible': True}

# %% [markdown]
# From above, we can see that **time** does not have a data level, whereas **dissolved_oxygen** is a **L2** level product.

# %% [markdown]
# The function ```get_parameter_data_levels``` will take in the metadata you requested and return the relevant data levels for the parameter

# %%
data_levels = get_parameter_data_levels(metadata)
data_levels
# Out:
# {'PD10': None,
#  'PD1005': None,
#  'PD11': None,
#  'PD12': None,
#  'PD14': 2,
#  'PD16': None,
#  'PD2605': None,
#  'PD2843': 1,
#  'PD312': None,
#  'PD7': None,
#  'PD863': None,
#  'PD940': 1,
#  'PD941': None,
#  'PD942': None,
#  'PD943': 0,
#  'PD944': None,
#  'PD945': None,
#  'PD946': None,
#  'PD947': None,
#  'PD948': None,
#  'PD949': None}

# %% [markdown]
# With the returned parameter IDs, we can now filter for the L1 and L2 data levels:

# %%
def filter_science_parameters(metadata, data_levels):
    """This function returns the science parameters for each datastream"""
    
    def filter_parameter_ids(pdId, pid_dict):
        data_level = pid_dict.get(pdId)
        if data_level is not None:
            if data_level > 0:
                return True
            else:
                return False
        else:
            return False
    
    # Filter the parameters for processed science parameters
    mask = metadata["pdId"].apply(lambda x: filter_parameter_ids(x, data_levels))
    metadata = metadata[mask]

    return metadata

# %%
science_variables = filter_science_parameters(metadata, data_levels)
science_variables
# Out:
#       pdId                     particleKey   type     shape      units  \
# 4     PD14                dissolved_oxygen  FLOAT  FUNCTION  umol kg-1
# 8    PD940  estimated_oxygen_concentration  FLOAT    SCALAR   umol L-1
# 20  PD2843     dosta_abcdjm_cspp_tc_oxygen  FLOAT  FUNCTION   umol L-1
#
#    fillValue                       stream  unsigned       method   count  \
# 4   -9999999  dosta_abcdjm_dcl_instrument     False  telemetered  110090
# 8   -9999999  dosta_abcdjm_dcl_instrument     False  telemetered  110090
# 20  -9999999  dosta_abcdjm_dcl_instrument     False  telemetered  110090
#
#                    beginTime                   endTime  \
# 4   2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 8   2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
# 20  2024-04-03T14:00:09.267Z  2024-09-16T12:03:01.321Z
#
#                          refdes
# 4   CP10CNSM-MFD37-04-DOSTAD000
# 8   CP10CNSM-MFD37-04-DOSTAD000
# 20  CP10CNSM-MFD37-04-DOSTAD000

# %% [markdown]
# Now, we can notice that the timestamps, etc did were filtered out. This is because they don't have a defined data product level. An additional wrinkle is that **```time```** is NOT the default dimension of delivered netCDF files - this means it needs to be specifically requested for data requests. This is something to be aware of when requesting only specific data variables.

# %% [markdown]
# ---
# ## Requesting Data
#
# ### Synchronous Data
# The fast(er) way to get data is via a **Synchronous** request. A synchronous request can accept the following specifications:
# * limit (required): specifies number of data points with a maximum of 20000
# * beginDT (optional): start date as YYYY-mm-ddTHH:MM:SS.fffZ format
# * endDT (optional): end date in same format as beginDT
# * parameters (optional): numeric IDs of which parameters to get
#
# If you do not specify the limit, the request defaults to an **asynchronous** request which is covered below.
#
# We'll go through the steps to narrow down to get just the dissolved oxygen data for the summer from the sensor mounted on the multi-function node (MFN) on the seafloor. The request we would build would have the following specifications:
# * limit: 20000
# * beginDT: 2024-06-01T00:00:01.000Z
# * endDT: 2024-09-01T00:00:00.000Z
# * parameters: 7 (time), 14 (dissolved oxygen)

# %%
method = "telemetered"
stream = "dosta_abcdjm_dcl_instrument"

# Request the oxygen data from the 
data_url = "/".join((URLS["data"], site, node, sensor, method, stream))

params = {
    "beginDT": "2024-06-01T00:00:01.000Z",
    "endDT": "2024-09-01T00:00:00.000Z",
    "limit": "20000",
}

data = get_api(data_url, params)
# Out:
# [{'raw_temperature': 164.10000610351562,
#   'red_phase': 7.914000034332275,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926201871

#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.644000053405762,
#   'ctdbp_cdef_dcl_instrument-depth': 29.611255898251894,
#   'serial_number': '394',
#   'temp_compensated_phase': 34.0260009765625,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.628867878311038,
#   'calibrated_phase': 34.0260009765625,
#   'ingestion_timestamp': 3926201871.421,
#   'port_timestamp': 3926188872.383,
#   'estimated_oxygen_saturation': 88.62799835205078,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188872.383,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 281.2879943847656,
#   'blue_phase': 41.96699905395508,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 281.2839388885258,
#   'red_amplitude': 735.5999755859375,
#   'blue_amplitude': 640.9000244140625,
#   'time': 3926188872.383,
#   'dissolved_oxygen': 225.0849710739937},
#  {'raw_temperature': 161.89999389648438,
#   'red_phase': 7.940999984741211,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926201871.339024,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52117404752147,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.647000312805176,
#   'ctdbp_cdef_dcl_instrument-depth': 29.611178186076287,
#   'serial_number': '394',
#   'temp_compensated_phase': 34.0260009765625,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.628966328917075,
#   'calibrated_phase': 34.0260009765625,
#   'ingestion_timestamp': 3926201871.422,
#   'port_timestamp': 3926188874.383,
#   'estimated_oxygen_saturation': 88.62300109863281,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188874.383,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 281.2550048828125,
#   'blue_phase': 41.96699905395508,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 281.2507633824439,
#   'red_amplitude': 735.4000244140625,
#   'blue_amplitude': 640.9000244140625,
#   'time': 3926188874.383,
#   'dissolved_oxygen': 225.058402856742},
#  {'raw_temperature': 161.8000030517578,
#   'red_phase': 7.942999839782715,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926201871.339056,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52121214514528,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.649999618530273,
#   'ctdbp_cdef_dcl_instrument-depth': 29.611100085349435,
#   'serial_number': '394',
#   'temp_compensated_phase': 34.02299880981445,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.629065271763936,
#   'calibrated_phase': 34.02299880981445,
#   'ingestion_timestamp': 3926201871.422,
#   'port_timestamp': 3926188876.3929996,
#   'estimated_oxygen_saturation': 88.64199829101562,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188876.3929996,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 281.2950134277344,
#   'blue_phase': 41.96500015258789,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 281.2866853159334,
#   'red_amplitude': 735.2000122070312,
#   'blue_amplitude': 640.9000244140625,
#   'time': 3926188876.3929996,
#   'dissolved_oxygen': 225.08712668434973},
#  {'raw_temperature': 161.6999969482422,
#   'red_phase': 7.942999839782715,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926201871.339085,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.521250072195066,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.652999877929688,
#   'ctdbp_cdef_dcl_instrument-depth': 29.611022334302028,
#   'serial_number': '394',
#   'temp_compensated_phase': 34.025001525878906,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.629163771615183,
#   'calibrated_phase': 34.025001525878906,
#   'ingestion_timestamp': 3926201871.4230003,
#   'port_timestamp': 3926188878.394,
#   'estimated_oxygen_saturation': 88.61799621582031,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188878.394,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 281.2019958496094,
#   'blue_phase': 41.96799850463867,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 281.20743378294355,
#   'red_amplitude': 735.0,
#   'blue_amplitude': 640.7999877929688,
#   'time': 3926188878.394,
#   'dissolved_oxygen': 225.02368817901962},
#  {'raw_temperature': 161.60000610351562,
#   'red_phase': 7.945000171661377,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926201871.339114,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52128777178569,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.654999732971191,
#   'ctdbp_cdef_dcl_instrument-depth': 29.610945049549468,
#   'serial_number': '394',
#   'temp_compensated_phase': 34.0260009765625,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.629261680735187,
#   'calibrated_phase': 34.0260009765625,
#   'ingestion_timestamp': 3926201871.4230003,
#   'port_timestamp': 3926188880.383,
#   'estimated_oxygen_saturation': 88.61299896240234,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188880.383,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 281.1719970703125,
#   'blue_phase': 41.97100067138672,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 281.16233868832296,
#   'red_amplitude': 734.9000244140625,
#   'blue_amplitude': 640.9000244140625,
#   'time': 3926188880.383,
#   'dissolved_oxygen': 224.98758197309374},
#  {'raw_temperature': 161.60000610351562,
#   'red_phase': 7.942999839782715,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926201871.33915,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52132566092109,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.656999588012695,
#   'ctdbp_cdef_dcl_instrument-depth': 29.61086737622713,
#   'serial_number': '394',
#   'temp_compensated_phase': 34.027000427246094,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.62936008211949,
#   'calibrated_phase': 34.027000427246094,
#   'ingestion_timestamp': 3926201871.4230003,
#   'port_timestamp': 3926188882.382,
#   'estimated_oxygen_saturation': 88.59600067138672,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188882.382,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 281.1050109863281,
#   'blue_phase': 41.97100067138672,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 281.11725057832325,
#   'red_amplitude': 734.7000122070312,
#   'blue_amplitude': 640.7999877929688,
#   'time': 3926188882.382,
#   'dissolved_oxygen': 224.95148125813364},
#  {'raw_temperature': 161.5,
#   'red_phase': 7.946000099182129,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926201871.339184,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52136356900917,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.65999984741211,
#   'ctdbp_cdef_dcl_instrument-depth': 29.610789664051524,
#   'serial_number': '394',
#   'temp_compensated_phase': 34.02299880981445,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.629458532725527,
#   'calibrated_phase': 34.02299880981445,
#   'ingestion_timestamp': 3926201871.424,
#   'port_timestamp': 3926188884.382,
#   'estimated_oxygen_saturation': 88.62200164794922,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188884.382,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 281.1719970703125,
#   'blue_phase': 41.96900177001953,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 281.17613866238395,
#   'red_amplitude': 734.5,
# ...
#   'red_phase': 7.919000148773193,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926239668.632625,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67137768276944,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.777000427246094,
#   'ctdbp_cdef_dcl_instrument-depth': 29.66411509640265,
#   'serial_number': '394',
#   'temp_compensated_phase': 33.97700119018555,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.991797219240523,
#   'calibrated_phase': 33.97700119018555,
#   'ingestion_timestamp': 3926239668.7609997,
#   'port_timestamp': 3926228438.602,
#   'estimated_oxygen_saturation': 88.7770004272461,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228438.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 280.9440002441406,
#   'blue_phase': 41.895999908447266,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 280.94260513741244,
#   'red_amplitude': 737.9000244140625,
#   'blue_amplitude': 639.7999877929688,
#   'time': 3926228438.602,
#   'dissolved_oxygen': 224.72111002600784},
#  {'raw_temperature': 157.39999389648438,
#   'red_phase': 7.921999931335449,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926239668.632654,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67120520689672,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.781999588012695,
#   'ctdbp_cdef_dcl_instrument-depth': 29.664024662568046,
#   'serial_number': '394',
#   'temp_compensated_phase': 33.97100067138672,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.991482054324544,
#   'calibrated_phase': 33.97100067138672,
#   'ingestion_timestamp': 3926239668.7609997,
#   'port_timestamp': 3926228440.602,
#   'estimated_oxygen_saturation': 88.81300354003906,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228440.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 281.031005859375,
#   'blue_phase': 41.893001556396484,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 281.0255124938539,
#   'red_amplitude': 737.5999755859375,
#   'blue_amplitude': 639.7000122070312,
#   'time': 3926228440.602,
#   'dissolved_oxygen': 224.78756939019107},
#  {'raw_temperature': 157.1999969482422,
#   'red_phase': 7.923999786376953,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926239668.6326847,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67103273102401,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.786999702453613,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663934228733442,
#   'serial_number': '394',
#   'temp_compensated_phase': 33.97200012207031,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.991166889408568,
#   'calibrated_phase': 33.97200012207031,
#   'ingestion_timestamp': 3926239668.7609997,
#   'port_timestamp': 3926228442.602,
#   'estimated_oxygen_saturation': 88.7969970703125,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228442.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 280.95001220703125,
#   'blue_phase': 41.895999908447266,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 280.94738282680646,
#   'red_amplitude': 737.4000244140625,
#   'blue_amplitude': 639.7000122070312,
#   'time': 3926228442.602,
#   'dissolved_oxygen': 224.72521795778928},
#  {'raw_temperature': 157.0,
#   'red_phase': 7.925000190734863,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926239668.632711,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.6708602551513,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.791999816894531,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663843794898835,
#   'serial_number': '394',
#   'temp_compensated_phase': 33.9739990234375,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.99085172449259,
#   'calibrated_phase': 33.9739990234375,
#   'ingestion_timestamp': 3926239668.762,
#   'port_timestamp': 3926228444.602,
#   'estimated_oxygen_saturation': 88.7770004272461,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228444.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 280.8550109863281,
#   'blue_phase': 41.89799880981445,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 280.84629916396733,
#   'red_amplitude': 737.0999755859375,
#   'blue_amplitude': 639.7000122070312,
#   'time': 3926228444.602,
#   'dissolved_oxygen': 224.64450590913594},
#  {'raw_temperature': 157.0,
#   'red_phase': 7.926000118255615,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926239668.632745,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67068777927858,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.793999671936035,
#   'ctdbp_cdef_dcl_instrument-depth': 29.66375336106423,
#   'serial_number': '394',
#   'temp_compensated_phase': 33.98899841308594,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.990536559576613,
#   'calibrated_phase': 33.98899841308594,
#   'ingestion_timestamp': 3926239668.762,
#   'port_timestamp': 3926228446.602,
#   'estimated_oxygen_saturation': 88.66100311279297,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228446.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 280.4750061035156,
#   'blue_phase': 41.915000915527344,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 280.47964677579495,
#   'red_amplitude': 736.7000122070312,
#   'blue_amplitude': 640.0999755859375,
#   'time': 3926228446.602,
#   'dissolved_oxygen': 224.35136940651765},
#  {'raw_temperature': 157.1999969482422,
#   'red_phase': 7.928999900817871,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926239668.632772,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67051538967868,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.786999702453613,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663662972464827,
#   'serial_number': '394',
#   'temp_compensated_phase': 34.02899932861328,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.990221552306812,
#   'calibrated_phase': 34.02899932861328,
#   'ingestion_timestamp': 3926239668.762,
#   'port_timestamp': 3926228448.601,
#   'estimated_oxygen_saturation': 88.38200378417969,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228448.601,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 279.63800048828125,
#   'blue_phase': 41.95800018310547,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 279.6397802333789,
#   'red_amplitude': 736.5,
#   'blue_amplitude': 641.0999755859375,
#   'time': 3926228448.601,
#   'dissolved_oxygen': 223.67971547165942},
#  {'raw_temperature': 157.60000610351562,
#   'red_phase': 7.931000232696533,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926239668.632798,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67034291380596,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.776000022888184,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663572538630223,
#   'serial_number': '394',
#   'temp_compensated_phase': 34.0099983215332,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.989906387390835,
#   'calibrated_phase': 34.0099983215332,
#   'ingestion_timestamp': 3926239668.762,
#   'port_timestamp': 3926228450.601,
#   'estimated_oxygen_saturation': 88.53600311279297,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228450.601,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 280.1940002441406,
#   'blue_phase': 41.941001892089844,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 280.1958483059423,
#   'red_amplitude': 736.2999877929688,
#   'blue_amplitude': 640.5999755859375,
#   'time': 3926228450.601,
#   'dissolved_oxygen': 224.12464887307144},
#  {'raw_temperature': 157.6999969482422,
#   'red_phase': 7.931000232696533,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926239668.632824,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67017043793325,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.772000312805176,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663482104795616,
#   'serial_number': '394',
#   'temp_compensated_phase': 34.016998291015625,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.989591222474857,
#   'calibrated_phase': 34.016998291015625,
#   'ingestion_timestamp': 3926239668.763,
#   'port_timestamp': 3926228452.601,
#   'estimated_oxygen_saturation': 88.48999786376953,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228452.601,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 280.0690002441406,
#   'blue_phase': 41.94900131225586,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 280.0793589599614,
#   'red_amplitude': 736.0,
#   'blue_amplitude': 640.7000122070312,
#   'time': 3926228452.601,
#   'dissolved_oxygen': 224.03161344610774},
#  {'raw_temperature': 157.6999969482422,
#   'red_phase': 7.933000087738037,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926239668.632854,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.66999787578773,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.772000312805176,
#   'ctdbp_cdef_dcl_instrument-depth': 29.66339162572581,
#   'serial_number': '394',
#   'temp_compensated_phase': 33.99800109863281,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.989275899912702,
#   'calibrated_phase': 33.99800109863281,
#   'ingestion_timestamp': 3926239668.763,
#   'port_timestamp': 3926228454.602,
#   'estimated_oxygen_saturation': 88.62799835205078,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228454.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 280.5069885253906,
#   'blue_phase': 41.930999755859375,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 280.51513349126003,
#   'red_amplitude': 735.7999877929688,
#   'blue_amplitude': 640.2000122070312,
#   'time': 3926228454.602,
#   'dissolved_oxygen': 224.38032650720177},
#  {'raw_temperature': 157.60000610351562,
#   'red_phase': 7.934000015258789,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926239668.632881,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.669825486187825,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.77400016784668,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663301237126408,
#   'serial_number': '394',
#   'temp_compensated_phase': 33.983001708984375,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.988960892642902,
#   'calibrated_phase': 33.983001708984375,
#   'ingestion_timestamp': 3926239668.763,
#   'port_timestamp': 3926228456.601,
#   'estimated_oxygen_saturation': 88.73600006103516,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228456.601,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 280.8340148925781,
#   'blue_phase': 41.91699981689453,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 280.8377012663848,
#   'red_amplitude': 735.5999755859375,
#   'blue_amplitude': 639.7999877929688,
#   'time': 3926228456.601,
#   'dissolved_oxygen': 224.6384872333307},
#  {'raw_temperature': 157.5,
#   'red_phase': 7.935999870300293,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926239668.632909,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.669575568627536,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.777999877929688,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663170198489198,
#   'serial_number': '394',
#   'temp_compensated_phase': 33.97700119018555,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.988504218641781,
#   'calibrated_phase': 33.97700119018555,
#   'ingestion_timestamp': 3926239668.763,
#   'port_timestamp': 3926228459.499,
#   'estimated_oxygen_saturation': 88.77100372314453,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228459.499,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 280.91900634765625,
#   'blue_phase': 41.91299819946289,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 280.93158482810264,
#   'red_amplitude': 735.2999877929688,
#   'blue_amplitude': 639.5999755859375,
#   'time': 3926228459.499,
#   'dissolved_oxygen': 224.71379094935062},
#  {'raw_temperature': 157.39999389648438,
#   'red_phase': 7.935999870300293,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926239668.632936,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.66948044816959,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.782999992370605,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663120324221996,
#   'serial_number': '394',
#   'temp_compensated_phase': 33.97800064086914,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.98833040516477,
#   'calibrated_phase': 33.97800064086914,
#   'ingestion_timestamp': 3926239668.764,
#   'port_timestamp': 3926228460.602,
#   'estimated_oxygen_saturation': 88.76300048828125,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228460.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 280.8680114746094,
#   'blue_phase': 41.91400146484375,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 280.85348038862554,
#   'red_amplitude': 735.2000122070312,
#   'blue_amplitude': 639.5999755859375,
#   'time': 3926228460.602,
#   'dissolved_oxygen': 224.65139508651245},
#  {'raw_temperature': 157.1999969482422,
#   'red_phase': 7.936999797821045,
#   'dcl_controller_timestamp': 'empty',
#   'product_number': 4831,
#   'driver_timestamp': 3926239668.632962,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.66930805856968,
#   'internal_timestamp': 0.0,
#   'optode_temperature': 14.788000106811523,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663029935622593,
#   'serial_number': '394',
#   'temp_compensated_phase': 33.974998474121094,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.988015397894971,
#   'calibrated_phase': 33.974998474121094,
#   'ingestion_timestamp': 3926239668.764,
#   'port_timestamp': 3926228462.601,
#   'estimated_oxygen_saturation': 88.77200317382812,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228462.601,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'estimated_oxygen_concentration': 280.8689880371094,
#   'blue_phase': 41.9119987487793,
#   'preferred_timestamp': 'port_timestamp',
#   'dosta_abcdjm_cspp_tc_oxygen': 280.8673987869327,
#   'red_amplitude': 734.9000244140625,
#   'blue_amplitude': 639.5,
#   'time': 3926228462.601,
#   'dissolved_oxygen': 224.66267131829636},
#  ...]

# %% [markdown]
# We'll put the data, which is in a JSON object, into a pandas dataframe for easier reading and parsing:

# %%
df = pd.DataFrame(data)
df.head(10)
# Out:
#    raw_temperature  red_phase dcl_controller_timestamp  product_number  \
# 0       164.100006      7.914                    empty            4831
# 1       164.000000      7.910                    empty            4831
# 2       164.000000      7.908                    empty            4831
# 3       164.000000      7.908                    empty            4831
# 4       163.899994      7.910                    empty            4831
# 5       163.899994      7.910                    empty            4831
# 6       163.800003      7.909                    empty            4831
# 7       163.800003      7.912                    empty            4831
# 8       163.699997      7.910                    empty            4831
# 9       163.699997      7.911                    empty            4831
#
#    driver_timestamp  ctdbp_cdef_dcl_instrument-sea_water_practical_salinity  \
# 0      3.926202e+09                                          32.520149
# 1      3.926202e+09                                          32.520149
# 2      3.926202e+09                                          32.520163
# 3      3.926202e+09                                          32.520177
# 4      3.926202e+09                                          32.520192
# 5      3.926202e+09                                          32.520206
# 6      3.926202e+09                                          32.520220
# 7      3.926202e+09                                          32.520235
# 8      3.926202e+09                                          32.520249
# 9      3.926202e+09                                          32.520264
#
#    internal_timestamp  optode_temperature  ctdbp_cdef_dcl_instrument-depth  \
# 0                 0.0              14.582                        29.613818
# 1                 0.0              14.584                        29.613818
# 2                 0.0              14.585                        29.613726
# 3                 0.0              14.586                        29.613628
# 4                 0.0              14.587                        29.613531
# 5                 0.0              14.588                        29.613433
# 6                 0.0              14.589                        29.613335
# 7                 0.0              14.591                        29.613238
# 8                 0.0              14.593                        29.613140
# 9                 0.0              14.594                        29.613043
#
#   serial_number  ...  estimated_oxygen_saturation  \
# 0           394  ...                    88.695999
# 1           394  ...                    88.693001
# 2           394  ...                    88.677002
# 3           394  ...                    88.690002
# 4           394  ...                    88.686996
# 5           394  ...                    88.674004
# 6           394  ...                    88.681000
# 7           394  ...                    88.689003
# 8           394  ...                    88.674004
# 9           394  ...                    88.676003
#
#                                                   pk  \
# 0  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...
# 1  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...
# 2  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...
# 3  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...
# 4  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...
# 5  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...
# 6  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...
# 7  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...
# 8  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...
# 9  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...
#
#    estimated_oxygen_concentration  blue_phase  preferred_timestamp  \
# 0                      281.881012   41.944000       port_timestamp
# 1                      281.864014   41.939999       port_timestamp
# 2                      281.807007   41.939999       port_timestamp
# 3                      281.842010   41.937000       port_timestamp
# 4                      281.826996   41.939999       port_timestamp
# 5                      281.778992   41.942001       port_timestamp
# 6                      281.790985   41.938999       port_timestamp
# 7                      281.808014   41.941002       port_timestamp
# 8                      281.747986   41.941002       port_timestamp
# 9                      281.746002   41.941002       port_timestamp
#
#    dosta_abcdjm_cspp_tc_oxygen red_amplitude  blue_amplitude          time  \
# 0                   281.878420    745.599976      642.299988  3.926189e+09
# 1                   281.856245    744.599976      642.200012  3.926189e+09
# 2                   281.798982    744.000000      642.200012  3.926189e+09
# 3                   281.834060    743.500000      642.099976  3.926189e+09
# 4                   281.822979    743.200012      642.099976  3.926189e+09
# 5                   281.765724    742.900024      642.099976  3.926189e+09
# 6                   281.800808    742.500000      641.900024  3.926189e+09
# 7                   281.801679    742.200012      641.900024  3.926189e+09
# 8                   281.756464    741.799988      641.900024  3.926189e+09
# 9                   281.745387    741.400024      641.700012  3.926189e+09
#
#   dissolved_oxygen
# 0       225.561025
# 1       225.543281
# 2       225.497475
# 3       225.525562
# 4       225.516712
# 5       225.470914
# 6       225.499006
# 7       225.499720
# 8       225.463556
# 9       225.454708
#
# [10 rows x 25 columns]

# %% [markdown]
# Query all of the different column names which are the different parameters returned in the data request we just made:

# %%
df.columns
# Out:
# Index(['raw_temperature', 'red_phase', 'dcl_controller_timestamp',
#        'product_number', 'driver_timestamp',
#        'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity',
#        'internal_timestamp', 'optode_temperature',
#        'ctdbp_cdef_dcl_instrument-depth', 'serial_number',
#        'temp_compensated_phase',
#        'ctdbp_cdef_dcl_instrument-sea_water_temperature', 'calibrated_phase',
#        'ingestion_timestamp', 'port_timestamp', 'estimated_oxygen_saturation',
#        'pk', 'estimated_oxygen_concentration', 'blue_phase',
#        'preferred_timestamp', 'dosta_abcdjm_cspp_tc_oxygen', 'red_amplitude',
#        'blue_amplitude', 'time', 'dissolved_oxygen'],
#       dtype='object')

# %% [markdown]
# That is a lot of data that was returned that we aren't necessarily interested in. Let's narrow our request to just the **dissolved_oxygen**, which from above we know has a parameter ID of PD14:

# %%
# Select the method and stream
method = "telemetered"
stream = "dosta_abcdjm_dcl_instrument"

# Build the base url to request the data
data_url = "/".join((URLS["data"], site, node, sensor, method, stream))

# Add in the limits to the data request
params = {
    "beginDT": "2024-06-01T00:00:01.000Z",
    "endDT": "2024-09-01T00:00:00.000Z",
    "limit": "20000",
    "parameters": "14"
}

# Request the data
data = get_api(data_url, params)
data
# Out:
# [{'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52014920486027,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188810.491,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.56102503141608,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.625783578269637,
#   'ctdbp_cdef_dcl_instrument-depth': 29.613818472278684},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52014922643034,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188810.494,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.54328051090707,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.625783733070861,
#   'ctdbp_cdef_dcl_instrument-depth': 29.613818325828507},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52016283813503,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188812.387,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.4974749596335,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.625881419729597,
#   'ctdbp_cdef_dcl_instrument-depth': 29.613725909062442},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52017721922724,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188814.387,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.52556208497555,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.625984628025675,
#   'ctdbp_cdef_dcl_instrument-depth': 29.61362826853426},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52019159312601,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188816.3859997,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.51671226755386,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.62608778469674,
#   'ctdbp_cdef_dcl_instrument-depth': 29.613530676846086},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52020597421822,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188818.3859997,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.47091384708227,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.62619099299282,
#   'ctdbp_cdef_dcl_instrument-depth': 29.613433036317904},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.520220355310435,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188820.3859997,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.49900587693296,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.626294201288898,
#   'ctdbp_cdef_dcl_instrument-depth': 29.613335395789726},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52023473640266,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188822.3859997,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.4997202870447,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.626397409584978,
#   'ctdbp_cdef_dcl_instrument-depth': 29.613237755261544},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52024911749487,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188824.3859997,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.4635559491078,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.626500617881057,
#   'ctdbp_cdef_dcl_instrument-depth': 29.613140114733365},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52026448085781,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188826.395,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.4547077445651,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.626604105079945,
#   'ctdbp_cdef_dcl_instrument-depth': 29.61304281201453},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52030221835378,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188828.3859997,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.52912893749925,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.626702112643422,
#   'ctdbp_cdef_dcl_instrument-depth': 29.612965449555425},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52034012644185,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188830.3859997,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.4744952385822,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.626800563249459,
#   'ctdbp_cdef_dcl_instrument-depth': 29.61288773737982},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.520378015586296,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188832.385,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.3092482210537,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.626898964657233,
#   'ctdbp_cdef_dcl_instrument-depth': 29.612810064038953},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52041592367437,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188834.385,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.41168349994737,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.62699741526327,
#   'ctdbp_cdef_dcl_instrument-depth': 29.612732351863347},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52045383176244,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188836.385,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.3017432951945,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.627095865869308,
#   'ctdbp_cdef_dcl_instrument-depth': 29.61265463968774},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52049173985051,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188838.385,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.30241316155312,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.627194316475345,
#   'ctdbp_cdef_dcl_instrument-depth': 29.612576927512134},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52052964793859,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188840.385,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.26625462271926,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.627292767081382,
#   'ctdbp_cdef_dcl_instrument-depth': 29.612499215336527},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52056755602666,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188842.385,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.23965419388642,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.62739121768742,
#   'ctdbp_cdef_dcl_instrument-depth': 29.61242150316092},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52060546411474,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188844.385,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.27723764876336,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.627489668293457,
#   'ctdbp_cdef_dcl_instrument-depth': 29.612343790985314},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52064337220281,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188846.385,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 225.29633750627767,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.

#   'ctdbp_cdef_dcl_instrument-depth': 29.663662972464827},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67034291380596,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228450.601,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 224.12464887307144,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.989906387390835,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663572538630223},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67017043793325,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228452.601,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 224.03161344610774,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.989591222474857,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663482104795616},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.66999787578773,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228454.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 224.38032650720177,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.989275899912702,
#   'ctdbp_cdef_dcl_instrument-depth': 29.66339162572581},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.669825486187825,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228456.601,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 224.6384872333307,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.988960892642902,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663301237126408},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.669575568627536,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228459.499,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 224.71379094935062,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.988504218641781,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663170198489198},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.66948044816959,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228460.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 224.65139508651245,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.98833040516477,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663120324221996},
#  {'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.66930805856968,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228462.601,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'},
#   'dissolved_oxygen': 224.66267131829636,
#   'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.988015397894971,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663029935622593},
#  ...]

# %% [markdown]
# Put the data, which is in a JSON object, into a pandas dataframe:

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#    ctdbp_cdef_dcl_instrument-sea_water_practical_salinity  \
# 0                                          32.520149
# 1                                          32.520149
# 2                                          32.520163
# 3                                          32.520177
# 4                                          32.520192
#
#                                                   pk  dissolved_oxygen  \
# 0  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...        225.561025
# 1  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...        225.543281
# 2  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...        225.497475
# 3  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...        225.525562
# 4  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...        225.516712
#
#    ctdbp_cdef_dcl_instrument-sea_water_temperature  \
# 0                                        14.625784
# 1                                        14.625784
# 2                                        14.625881
# 3                                        14.625985
# 4                                        14.626088
#
#    ctdbp_cdef_dcl_instrument-depth
# 0                        29.613818
# 1                        29.613818
# 2                        29.613726
# 3                        29.613628
# 4                        29.613531

# %% [markdown]
# We requested just the dissolved oxygen data, but we also got **ctdbp_cdef_dcl_instrument-sea_water_temperature** and **ctdbp_cdef_dcl_instrument-sea_water_practical_salinity** even though we didn't request them. So what are they? They are the seawater temperature and practical salinity needed to calculate the dissolved oxygen concentration from the DO measured by the instrument. The part before **-** in the names tell you the data stream the parameter comes from.
#
# However, this time we don't have any **time** parameter! That's because we forgot to request it. So let's try this once more, including the **time** parameter id of **7**:

# %%
# Select the method and stream
method = "telemetered"
stream = "dosta_abcdjm_dcl_instrument"

# Build the base url to request the data
data_url = "/".join((URLS["data"], site, node, sensor, method, stream))

# Add in the limits to the data request, this time remembering to include "time" parameter "7"
params = {
    "beginDT": "2024-06-01T00:00:01.000Z",
    "endDT": "2024-09-01T00:00:00.000Z",
    "limit": "20000",
    "parameters": "7,14"
}

# Request the data
data = get_api(data_url, params)
data
# Out:
# [{'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.625783578269637,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52014920486027,
#   'dissolved_oxygen': 225.56102503141608,
#   'time': 3926188810.491,
#   'ctdbp_cdef_dcl_instrument-depth': 29.613818472278684,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188810.491,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.625783733070861,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52014922643034,
#   'dissolved_oxygen': 225.54328051090707,
#   'time': 3926188810.494,
#   'ctdbp_cdef_dcl_instrument-depth': 29.613818325828507,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188810.494,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.625881419729597,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52016283813503,
#   'dissolved_oxygen': 225.4974749596335,
#   'time': 3926188812.387,
#   'ctdbp_cdef_dcl_instrument-depth': 29.613725909062442,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188812.387,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.625984628025675,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52017721922724,
#   'dissolved_oxygen': 225.52556208497555,
#   'time': 3926188814.387,
#   'ctdbp_cdef_dcl_instrument-depth': 29.61362826853426,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188814.387,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.62608778469674,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52019159312601,
#   'dissolved_oxygen': 225.51671226755386,
#   'time': 3926188816.3859997,
#   'ctdbp_cdef_dcl_instrument-depth': 29.613530676846086,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188816.3859997,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.62619099299282,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.52020597421822,
#   'dissolved_oxygen': 225.47091384708227,
#   'time': 3926188818.3859997,
#   'ctdbp_cdef_dcl_instrument-depth': 29.613433036317904,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926188818.3859997,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.626294201288898,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.520220355310435,
#   'dissolved_oxygen': 225.49900587693296,
#   'time': 3926188820.3859997,
#   'ctdbp_cdef_dcl_instrument-depth': 29.

#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228432.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.992427549072477,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.671722634514865,
#   'dissolved_oxygen': 224.5442971461012,
#   'time': 3926228434.602,
#   'ctdbp_cdef_dcl_instrument-depth': 29.66429596407186,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228434.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.9921123841565,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67155015864215,
#   'dissolved_oxygen': 224.581927473783,
#   'time': 3926228436.602,
#   'ctdbp_cdef_dcl_instrument-depth': 29.664205530237254,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228436.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.991797219240523,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67137768276944,
#   'dissolved_oxygen': 224.72111002600784,
#   'time': 3926228438.602,
#   'ctdbp_cdef_dcl_instrument-depth': 29.66411509640265,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228438.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.991482054324544,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67120520689672,
#   'dissolved_oxygen': 224.78756939019107,
#   'time': 3926228440.602,
#   'ctdbp_cdef_dcl_instrument-depth': 29.664024662568046,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228440.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.991166889408568,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67103273102401,
#   'dissolved_oxygen': 224.72521795778928,
#   'time': 3926228442.602,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663934228733442,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228442.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.99085172449259,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.6708602551513,
#   'dissolved_oxygen': 224.64450590913594,
#   'time': 3926228444.602,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663843794898835,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228444.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.990536559576613,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67068777927858,
#   'dissolved_oxygen': 224.35136940651765,
#   'time': 3926228446.602,
#   'ctdbp_cdef_dcl_instrument-depth': 29.66375336106423,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228446.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.990221552306812,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67051538967868,
#   'dissolved_oxygen': 223.67971547165942,
#   'time': 3926228448.601,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663662972464827,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228448.601,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.989906387390835,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67034291380596,
#   'dissolved_oxygen': 224.12464887307144,
#   'time': 3926228450.601,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663572538630223,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228450.601,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.989591222474857,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.67017043793325,
#   'dissolved_oxygen': 224.03161344610774,
#   'time': 3926228452.601,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663482104795616,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228452.601,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.989275899912702,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.66999787578773,
#   'dissolved_oxygen': 224.38032650720177,
#   'time': 3926228454.602,
#   'ctdbp_cdef_dcl_instrument-depth': 29.66339162572581,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228454.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.988960892642902,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.669825486187825,
#   'dissolved_oxygen': 224.6384872333307,
#   'time': 3926228456.601,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663301237126408,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228456.601,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.988504218641781,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.669575568627536,
#   'dissolved_oxygen': 224.71379094935062,
#   'time': 3926228459.499,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663170198489198,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228459.499,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.98833040516477,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.66948044816959,
#   'dissolved_oxygen': 224.65139508651245,
#   'time': 3926228460.602,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663120324221996,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228460.602,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  {'ctdbp_cdef_dcl_instrument-sea_water_temperature': 14.988015397894971,
#   'ctdbp_cdef_dcl_instrument-sea_water_practical_salinity': 32.66930805856968,
#   'dissolved_oxygen': 224.66267131829636,
#   'time': 3926228462.601,
#   'ctdbp_cdef_dcl_instrument-depth': 29.663029935622593,
#   'pk': {'node': 'MFD37',
#    'stream': 'dosta_abcdjm_dcl_instrument',
#    'subsite': 'CP10CNSM',
#    'deployment': 1,
#    'time': 3926228462.601,
#    'sensor': '04-DOSTAD000',
#    'method': 'telemetered'}},
#  ...]

# %%
# Put the data into a dataframe
df = pd.DataFrame(data)

# Convert the time stamps from a string into a datetime object
df["time"] = df["time"].apply(lambda x: ntp_seconds_to_datetime(x))

# Get the deployment number from the "pk" dictionary
df["deployment"] = df["pk"].apply(lambda x: int(x["deployment"]))    
df.head(10)
# Out:
#    ctdbp_cdef_dcl_instrument-sea_water_temperature  \
# 0                                        14.625784
# 1                                        14.625784
# 2                                        14.625881
# 3                                        14.625985
# 4                                        14.626088
# 5                                        14.626191
# 6                                        14.626294
# 7                                        14.626397
# 8                                        14.626501
# 9                                        14.626604
#
#    ctdbp_cdef_dcl_instrument-sea_water_practical_salinity  dissolved_oxygen  \
# 0                                          32.520149             225.561025
# 1                                          32.520149             225.543281
# 2                                          32.520163             225.497475
# 3                                          32.520177             225.525562
# 4                                          32.520192             225.516712
# 5                                          32.520206             225.470914
# 6                                          32.520220             225.499006
# 7                                          32.520235             225.499720
# 8                                          32.520249             225.463556
# 9                                          32.520264             225.454708
#
#                      time  ctdbp_cdef_dcl_instrument-depth  \
# 0 2024-06-01 00:00:10.491                        29.613818
# 1 2024-06-01 00:00:10.494                        29.613818
# 2 2024-06-01 00:00:12.387                        29.613726
# 3 2024-06-01 00:00:14.387                        29.613628
# 4 2024-06-01 00:00:16.386                        29.613531
# 5 2024-06-01 00:00:18.386                        29.613433
# 6 2024-06-01 00:00:20.386                        29.613335
# 7 2024-06-01 00:00:22.386                        29.613238
# 8 2024-06-01 00:00:24.386                        29.613140
# 9 2024-06-01 00:00:26.395                        29.613043
#
#                                                   pk  deployment
# 0  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...           1
# 1  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...           1
# 2  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...           1
# 3  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...           1
# 4  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...           1
# 5  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...           1
# 6  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...           1
# 7  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...           1
# 8  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...           1
# 9  {'node': 'MFD37', 'stream': 'dosta_abcdjm_dcl_...           1

# %% [markdown]
# Now we have everything we could want in order to begin visualizing and analyzing the oxygen data we requested.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(21,15))

ax[0].plot(df["time"], df["dissolved_oxygen"], marker=".", linestyle="", color="tab:blue")
ax[0].set_ylabel("Dissolved Oxygen \n[umol/kg]", fontsize=16, weight="bold")
#ax[0].set_ylim((250, 400))
ax[0].grid()

ax[1].plot(df["time"], df["ctdbp_cdef_dcl_instrument-sea_water_temperature"], marker=".", linestyle="", color="tab:red")
ax[1].set_ylabel("Seawater Temperature \n[deg_C]", fontsize=16, weight="bold")
ax[1].grid()

ax[2].plot(df["time"], df["ctdbp_cdef_dcl_instrument-sea_water_practical_salinity"], marker=".", linestyle="", color="tab:green")
ax[2].set_ylabel("Practical Salinity", fontsize=16, weight="bold")
ax[2].set_ylim((31.5, 33.5))
ax[2].grid()

# %% [markdown]
# Looking at the data, there seems to be a lot of missing data. Wonder what could be going on? The first place to check are the **annotations**.

# %% [markdown]
# ---
# ## Annotations
# Annotations are technical notes or qualitative data assessments of the instrument added by staff from the institutions operating the sensors. They represent the first human-in-the-loop (HITL) quality control review of the data coming from the sensor, and may contain important information about the state of the instrument, such as the presence of biofouling, power issues, communications disruptions, and other such issues.
#
# Annotations are ideal for removing known and identified bad data from a dataset before further processing. While it is not within the purview of OOI to comprehensively flag all such issues, such that additional end user QA/QC is required, existing annotations will provide valuable and time-saving information to support end user analysis.
#
# An annotation downloaded from the OOI Data Portal is associated with a particular reference designator and not an individual instrument. It may also be further limited to a particular stream for a given reference designator, such as the pco2w_abc_dcl_instrument_recovered for recovered data from the SAMI-pCO2 instrument, as well as further limited to particular parameters. Annotations are either open-ended, with a start time (beginDT) and no end time (endDT), or may have both a start and end time. Times are returned in unix epoch microseconds. Lastly, a qcFlag may be assigned to a particular annotation following the QARTOD flagging conventions described above.

# %%
print(f"The annotation endpoint is: {URLS['anno']}")
# Out:
# The annotation endpoint is: https://ooinet.oceanobservatories.org/api/m2m/12580/anno/find

# %% [markdown]
# Now construct the annotation request. Once we get the annotations, we have to convert the beginDT and endDT from the unix epoch time milliseconds into a readable time stamp:

# %%
params = {
    "beginDT": "2024-06-01T00:00:01.000Z",
    "endDT": "2024-09-01T00:00:00.000Z",
}

annotations = get_annotations(refdes, beginDT="2024-06-01T00:00:01.000Z", endDT="2024-09-01T00:00:00.000Z")
annotations["beginDT"] = annotations["beginDT"].apply(lambda x: convert_time(x))
annotations["endDT"] = annotations["endDT"].apply(lambda x: convert_time(x) if not np.isnan(x) else x)
annotations
annotations
# Out:
#               @class    id   subsite   node sensor method stream  \
# 0  .AnnotationRecord  5604  CP10CNSM  MFD37   None   None   None
# 1  .AnnotationRecord  5718  CP10CNSM  MFD37   None   None   None
#
#               beginDT               endDT  \
# 0 2024-05-07 13:00:00 2024-09-09 12:00:00
# 1 2024-07-15 12:00:00                 NaT
#
#                                           annotation  exclusionFlag  \
# 0  Deployment 1:  DCL37 power was temporarily dis...          False
# 1  Deployment 1: DCL37 was re-enabled on 2024-07-...          False
#
#              source qcFlag parameters
# 0  cdobson@whoi.edu      9         []
# 1  cdobson@whoi.edu      0         []

# %% [markdown]
# Print out the annotation text for each row in the table above:

# %%
for index in annotations.index:
    start, stop, anno = annotations.loc[index, "beginDT"], annotations.loc[index, "endDT"], annotations.loc[index, "annotation"]
    print(f"{start} to {stop}: {anno}\n")
# Out:
# 2024-05-07 13:00:00 to 2024-09-09 12:00:00: Deployment 1:  DCL37 power was temporarily disabled throughout this deployment due to the buoy's low power state. No telemetered data is expected for these periods without power. Instruments that do not collect data on battery power will have gaps in their recovered data for these times. Known down-times include 2024-05-07 to 2024-05-23 2024-06-10 to 2024-07-25 and 2024-08-06 to 2024-09-09.
#
# 2024-07-15 12:00:00 to NaT: Deployment 1: DCL37 was re-enabled on 2024-07-15 and was put on a limited power schedule to conserve power. It will be powered four times a day rather than every hour.

# %% [markdown]
# So it looks like power issues limited the amount of data that could be collected and telemetered.

# %% [markdown]
# ---
# ## Asynchronous Data Request
#
# Asynchronous data request are not limited in the number of data points that you can request. Additionally, they allow you to request **netCDF** and **csv** data formats as well as **JSON**. However, they are slower than synchronous data requests and, depending on the dataset, can be very very large. The available request specificiations include:
# * limit (required): if not specified, defaults netCDF
# * beginDT (optional): start date as YYYY-mm-ddTHH:MM:SS.fffZ format
# * endDT (optional): end date in same format as beginDT
# * parameters (optional): numeric IDs of which parameters to get
# * include_provenance (optional, default False): include a provenance file which specifies data processing paths
# * include_annotations (optional, default False): include a file with data annotations
#
# For the example we walked through above with the synchronous request, we can similarly request the asynchronous version to get netCDF datasets. Our specifications will be:
# * beginDT: 2024-06-01T00:00:00.000Z
# * endDT: 2024-09-01T00:00:00.000Z
# * parameters: 7 (time), 14 (dissolved oxygen)

# %%
# Asynchronous 
data_url = "/".join((URLS["data"], site, node, sensor, method, stream))

params = {
    "beginDT": "2024-06-01T00:00:01.000Z",
    "endDT": "2024-09-01T00:00:00.000Z",
}

# %%
import time

# %%
# Get the urls
urls = get_api(data_url, params=params)
# Check the status of the dataset preparation
status_url = [url for url in urls["allURLs"] if re.match(r'.*async_results.*', url)][0]
status_url = status_url + "/status.txt"
status = SESSION.get(status_url)
# Hold until the dataset construction is finished
while status.status_code != requests.codes.ok:
    time.sleep(2)
    status = SESSION.get(status_url)
        
# Now fetch the thredds_url from the 
for d in urls['allURLs']:
    if 'thredds' in d:
        thredds_url = d

thredds_url
# Out:
# 'https://opendap-west.oceanobservatories.org/thredds/catalog/ooi/areed@whoi.edu/20240916T174150482Z-CP10CNSM-MFD37-04-DOSTAD000-telemetered-dosta_abcdjm_dcl_instrument/catalog.html'

# %%
urls
# Out:
# {'requestUUID': '6942d248-fc30-4869-bc96-6df28ca99683',
#  'outputURL': 'https://opendap-west.oceanobservatories.org/thredds/catalog/ooi/areed@whoi.edu/20240916T174150482Z-CP10CNSM-MFD37-04-DOSTAD000-telemetered-dosta_abcdjm_dcl_instrument/catalog.html',
#  'allURLs': ['https://opendap-west.oceanobservatories.org/thredds/catalog/ooi/areed@whoi.edu/20240916T174150482Z-CP10CNSM-MFD37-04-DOSTAD000-telemetered-dosta_abcdjm_dcl_instrument/catalog.html',
#   'https://downloads-west.oceanobservatories.org/async_results/areed@whoi.edu/20240916T174150482Z-CP10CNSM-MFD37-04-DOSTAD000-telemetered-dosta_abcdjm_dcl_instrument'],
#  'sizeCalculation': 1919338,
#  'timeCalculation': 60,
#  'numberOfSubJobs': 16}

# %% [markdown]
# Now, the url we want is the "thredds catalog" in the 'allURLs' dictionary entry above. We have to parse out the catalog for the netCDF files

# %%
from bs4 import BeautifulSoup

# %%
page = requests.get(thredds_url).text
soup = BeautifulSoup(page, "html.parser")
pattern = re.compile('.*\\.nc$')
catalog = sorted([node.get('href') for node in soup.find_all('a', text=pattern)])
catalog
# Out:
# ['catalog.html?dataset=ooi/areed@whoi.edu/20240916T174150482Z-CP10CNSM-MFD37-04-DOSTAD000-telemetered-dosta_abcdjm_dcl_instrument/deployment0001_CP10CNSM-MFD37-03-CTDBPC000-telemetered-ctdbp_cdef_dcl_instrument_20240531T230027.761000-20240909T180048.634000.nc',
#  'catalog.html?dataset=ooi/areed@whoi.edu/20240916T174150482Z-CP10CNSM-MFD37-04-DOSTAD000-telemetered-dosta_abcdjm_dcl_instrument/deployment0001_CP10CNSM-MFD37-04-DOSTAD000-telemetered-dosta_abcdjm_dcl_instrument_20240601T000010.491000-20240806T000301.207000.nc']

# %% [markdown]
# However, notice that there are some datasets which are NOT oxygen data. These include CTDBPC000, which supplies the practical salinity and temperature data necessary for calculating the oxygen concentration. We'll parse those out of the catalog and leave us with just the DOSTA datasets.

# %%
# Get rid of the unwanted datasets
catalog = [x for x in catalog if refdes in x.split("/")[-1]] 
catalog
# Out:
# ['catalog.html?dataset=ooi/areed@whoi.edu/20240916T174150482Z-CP10CNSM-MFD37-04-DOSTAD000-telemetered-dosta_abcdjm_dcl_instrument/deployment0001_CP10CNSM-MFD37-04-DOSTAD000-telemetered-dosta_abcdjm_dcl_instrument_20240601T000010.491000-20240806T000301.207000.nc']

# %% [markdown]
# In order to download the data, we want to get the catalog files from the **fileServer** url. Then we can download the netCDF files to whatever directory we want.

# %%
from urllib.request import urlretrieve

# %%
# To download, we need the fileServer
fileServer = URLS["fileServer"]
netCDF_files = [re.sub("catalog.html\?dataset=", fileServer, file) for file in catalog]

# Make a save directory
saveDir = f"../data/{refdes}/"
if not os.path.exists(saveDir):
    os.makedirs(saveDir)

for file in netCDF_files:
        filename = file.split("/")[-1]
        saveFile = "/".join((saveDir, filename))
        print(f"Saving {filename} to {saveFile} \n")
        urlretrieve(file, saveFile)

# %% [markdown]
# #### Packaged functions
# The steps outlined above have been simplified into several easier-to-use functions as part of the package with this tutorial.

# %%
# First, get the thredds_url
thredds_url = get_thredds_url(refdes, method, stream, goldCopy=False, beginDT=params["beginDT"], endDT=params["endDT"], parameters=params["parameters"])

# Second, access the catalog
catalog = get_thredds_catalog(thredds_url)

# Next , get rid of the unwanted datasets
catalog = [x for x in catalog if refdes in x.split("/")[-1]] 

# Lastly, download the datasets
saveDir = f"../data/{refdes}/"
download_netCDF_files(catalog, goldCopy=False, saveDir=saveDir)

# %% [markdown]
# ---
# ## Loading Data (TODO)

# %% [markdown]
# There are several ways to open the data. You might be tempted to utilize ```xarray.open_mfdataset``` feature to open all of the datasets at once into a single file. This will fail because moorings are deployed such that the new mooring goes into the water before the old mooring is recovered, leading to overlapping time periods. The ```open_mfdataset``` function requires increasing primary dimension. This can be avoided by using a ```preprocess``` routine to trim the overlapping portions of the datasets, but then you potentially lose some valuable data when two instruments are in the water at the same time!
#
# Instead, we can concatentate the datasets together. However, this is recommended only with smaller datasets; long timeseries or large datasets, especially profilers, will cause you to run out of working memory.

# %%
catalog
# Out:
# ['catalog.html?dataset=ooi/areed@whoi.edu/20240916T174150482Z-CP10CNSM-MFD37-04-DOSTAD000-telemetered-dosta_abcdjm_dcl_instrument/deployment0001_CP10CNSM-MFD37-04-DOSTAD000-telemetered-dosta_abcdjm_dcl_instrument_20240601T000010.491000-20240806T000301.207000.nc']

# %% [markdown]
# If opening directly from the web, you will need to substitute in the full URL for the OPENDAP server onto the catalog .nc files in order to have a full url to access and open the dataset.

# %%
dodsC = URLS["dodsC"]
catalog = [re.sub("catalog.html\?dataset=", dodsC, file) for file in catalog]
catalog
# Out:
# ['https://opendap.oceanobservatories.org/thredds/dodsC/ooi/areed@whoi.edu/20240916T174150482Z-CP10CNSM-MFD37-04-DOSTAD000-telemetered-dosta_abcdjm_dcl_instrument/deployment0001_CP10CNSM-MFD37-04-DOSTAD000-telemetered-dosta_abcdjm_dcl_instrument_20240601T000010.491000-20240806T000301.207000.nc']

# %%
ds = xr.open_dataset(catalog[0])
ds
# Out:
# <xarray.Dataset>
# Dimensions:                         (obs: 22919)
# Coordinates:
#   * obs                             (obs) int32 0 1 2 3 ... 22916 22917 22918
# Data variables: (12/28)
#     raw_temperature                 (obs) float32 ...
#     red_phase                       (obs) float32 ...
#     dcl_controller_timestamp        (obs) object ...
#     product_number                  (obs) float32 ...
#     driver_timestamp                (obs) datetime64[ns] ...
#     id                              (obs) |S64 ...
#     ...                              ...
#     dosta_abcdjm_cspp_tc_oxygen     (obs) float64 ...
#     red_amplitude                   (obs) float32 ...
#     depth                           (obs) float64 ...
#     blue_amplitude                  (obs) float32 ...
#     time                            (obs) datetime64[ns] ...
#     sea_water_temperature           (obs) float64 ...
# Attributes: (12/74)
#     _NCProperties:                      version=1|netcdflibversion=4.6.1|hdf5...
#     node:                               MFD37
#     comment:
#     publisher_email:
#     sourceUrl:                          http://oceanobservatories.org/
#     collection_method:                  telemetered
#     ...                                 ...
#     geospatial_vertical_positive:       down
#     lat:                                35.94988
#     lon:                                -75.11943
#     DODS.strlen:                        14
#     DODS.dimName:                       string14
#     DODS_EXTRA.Unlimited_Dimension:     obs

# %%
# Next, swap the primary data variable
ds = ds.swap_dims({"obs":"time"})
ds
# Out:
# <xarray.Dataset>
# Dimensions:                         (time: 22919)
# Coordinates:
#     obs                             (time) int32 0 1 2 3 ... 22916 22917 22918
#   * time                            (time) datetime64[ns] 2024-06-01T00:00:10...
# Data variables: (12/27)
#     raw_temperature                 (time) float32 ...
#     red_phase                       (time) float32 ...
#     dcl_controller_timestamp        (time) object ...
#     product_number                  (time) float32 ...
#     driver_timestamp                (time) datetime64[ns] ...
#     id                              (time) |S64 ...
#     ...                              ...
#     int_ctd_pressure                (time) float64 ...
#     dosta_abcdjm_cspp_tc_oxygen     (time) float64 ...
#     red_amplitude                   (time) float32 ...
#     depth                           (time) float64 ...
#     blue_amplitude                  (time) float32 ...
#     sea_water_temperature           (time) float64 ...
# Attributes: (12/74)
#     _NCProperties:                      version=1|netcdflibversion=4.6.1|hdf5...
#     node:                               MFD37
#     comment:
#     publisher_email:
#     sourceUrl:                          http://oceanobservatories.org/
#     collection_method:                  telemetered
#     ...                                 ...
#     geospatial_vertical_positive:       down
#     lat:                                35.94988
#     lon:                                -75.11943
#     DODS.strlen:                        14
#     DODS.dimName:                       string14
#     DODS_EXTRA.Unlimited_Dimension:     obs

# %%
# And can rename some of the variables to make them easier to understand
rename = {
    'estimated_oxygen_concentration': 'oxygen_concentration',
    'estimated_oxygen_saturation': 'oxygen_saturation',
    'dosta_abcdjm_cspp_tc_oxygen': 'svu_oxygen_concentration',
    'dosta_abcdjm_cspp_tc_oxygen_qc_executed': 'svu_oxygen_concentration_qc_executed',
    'dosta_abcdjm_cspp_tc_oxygen_qc_results': 'svu_oxygen_concentration_qc_results',
    'dissolved_oxygen': 'oxygen_concentration_corrected',
    'dissolved_oxygen_qc_executed': 'oxygen_concentration_corrected_qc_executed',
    'dissolved_oxygen_qc_results': 'oxygen_concentration_corrected_qc_results',
    'int_ctd_pressure': 'seawater_pressure',
    'temp': 'seawater_temperature',
}

# %%
for var in ds.variables:
    if var in rename.keys():
        print(var)
        ds = ds.rename({var: rename.get(var)})
# Out:
# dissolved_oxygen
# estimated_oxygen_saturation
# estimated_oxygen_concentration
# int_ctd_pressure
# dosta_abcdjm_cspp_tc_oxygen

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                         (time: 22919)
# Coordinates:
#     obs                             (time) int32 0 1 2 3 ... 22916 22917 22918
#   * time                            (time) datetime64[ns] 2024-06-01T00:00:10...
# Data variables: (12/27)
#     raw_temperature                 (time) float32 ...
#     red_phase                       (time) float32 ...
#     dcl_controller_timestamp        (time) object ...
#     product_number                  (time) float32 ...
#     driver_timestamp                (time) datetime64[ns] ...
#     id                              (time) |S64 ...
#     ...                              ...
#     seawater_pressure               (time) float64 ...
#     svu_oxygen_concentration        (time) float64 ...
#     red_amplitude                   (time) float32 ...
#     depth                           (time) float64 ...
#     blue_amplitude                  (time) float32 ...
#     sea_water_temperature           (time) float64 ...
# Attributes: (12/74)
#     _NCProperties:                      version=1|netcdflibversion=4.6.1|hdf5...
#     node:                               MFD37
#     comment:
#     publisher_email:
#     sourceUrl:                          http://oceanobservatories.org/
#     collection_method:                  telemetered
#     ...                                 ...
#     geospatial_vertical_positive:       down
#     lat:                                35.94988
#     lon:                                -75.11943
#     DODS.strlen:                        14
#     DODS.dimName:                       string14
#     DODS_EXTRA.Unlimited_Dimension:     obs

# %% [markdown]
# Working on fixing a couple of the ooi-data-exploration bugs with loading data wrt to limited parameter datasets.

# %%
# First need to switch out

# %%
ds
