# %% [markdown]
# # Accessing OOI Data and Metadata through the M2M API
#
# Most users utilize the [OOI M2M API](https://oceanobservatories.org/ooi-m2m-interface/) to access (request and download) data from the various instruments and sensors deployed across the arrays. Indeed, the code in this repo is largely built around this activity. There are, however, additional API calls available to users that go beyond just requesting data. These can be used to request more information about, for example, the various sites, different deployments, instrument serial numbers, and calibration coefficients.
#
# All of this information, which is stored in the [OOI Asset Management Database](https://github.com/oceanobservatories/asset-management), is combined to form the metadata (the data about the data) that users can utilize to create data requests, re-process data, or add additional data to the requested data. This notebook will demonstrate how to use these API calls, which have been mapped to functions within this repo, to access and utilize the OOI metadata. To understand the terminalogy used below, please refer to the [README](https://github.com/oceanobservatories/ooi-data-explorations/tree/master/python#m2m-terminology) for this repo and to the [OOI website](https://oceanobservatories.org/research-arrays/).
#
# The functions were built based off of the [API Cheat Sheet](https://github.com/ooi-data-review/2018-data-workshops/raw/master/handouts/API%20Cheat%20Sheet.pdf) developed for the [2018 Early Career Data Workshops](https://oceanobservatories.org/data-workshops/) hosted at Rutgers University. They can be broken down into six categories:
#
# * Sensor Information: Develop lists about the various sites, nodes and sensors deployed by OOI, and lists of the data delivery methods, data streams, and the parameters included in, and the time ranges covered by each stream.
# * Preload Information: Pull information from the backend data base that defines streams and the parameters contained within a stream.
# * Deployment Information: Download deployment information (deployment number, dates, sensors deployed, location, etc).
# * Calibration Information: Download calibration data for an instrument defined by the site, node and sensor, or for a specific instrument as defined by it's unique ID (derived from the serial number)
# * Asset Information: In many ways a duplicate of the Calibration Information functions, with queires and results returned differing slightly.
# * Annotations: Use the site, node and sensor names to obtain annotations (notes and HITL QC assessments of the data) about the instrument of interest.
#
# Several of these functions will return a firehose of information. Users will need to spend time understanding the responses and how they can be used. The examples below will hopefully help with that process.

# %% [markdown]
# ## Sensor Information
#
# All of the functions used below return lists of the information a user can pull out of the [OOI M2M API](https://oceanobservatories.org/ooi-m2m-interface/) system. The first three functions imported below are hierarchical, in other words they are build on each other (e.g. listing the sites in OOI, then using a specific site to list the available nodes, and then using a specific site and node to list the available sensors). The combination of a specific site, node and sensor is used within OOI to create [the reference designator](https://oceanobservatories.org/knowledgebase/how-to-decipher-a-reference-designator/). The reference designator provides the unique code needed to access a specific instance of an instrument within OOI (e.g. the CTD on the midwater platform of the Oregon Shelf Surface mooring).
#
# The remaining three methods all provide different pieces of information about that specific instrument, or reference designator: data delivery methods, streams (aka datasets), the available parameters and the time ranges covered by the different streams.

# %%
import pprint as pp
import requests
import json

# import the functions used to list available information about sites, nodes and sensors ...
from ooi_data_explorations.common import list_sites, list_nodes, list_sensors

# ... and the more detailed information about a specific site, node and sensor (reference designator)
from ooi_data_explorations.common import list_methods, list_streams, list_metadata

# Some basics from the common package to construct our own requests
from ooi_data_explorations.common import BASE_URL, SENSOR_URL, AUTH

# %%
# create a list of all the sites in OOI
sites = list_sites()
sites
# Out:
# ['CE01ISSM',
#  'CE01ISSP',
#  'CE02SHBP',
#  'CE02SHSM',
#  'CE02SHSP',
#  'CE04OSBP',
#  'CE04OSPD',
#  'CE04OSPI',
#  'CE04OSPS',
#  'CE04OSSM',
#  'CE05MOAS',
#  'CE06ISSM',
#  'CE06ISSP',
#  'CE07SHSM',
#  'CE07SHSP',
#  'CE09OSPM',
#  'CE09OSSM',
#  'CP01CNPM',
#  'CP01CNSM',
#  'CP01CNSP',
#  'CP02PMCI',
#  'CP02PMCO',
#  'CP02PMUI',
#  'CP02PMUO',
#  'CP03ISPM',
#  'CP03ISSM',
#  'CP03ISSP',
#  'CP04OSPM',
#  'CP04OSSM',
#  'CP05MOAS',
#  'CP10CNSM',
#  'CP11NOSM',
#  'CP11SOSM',
#  'CP12CNSW',
#  'CP12WESW',
#  'CP13EAPM',
#  'CP13NOPM',
#  'CP13SOPM',
#  'CP14NEPM',
#  'CP14SEPM',
#  'CP15MOAS',
#  'CP16MOAS',
#  'GA01SUMO',
#  'GA02HYPM',
#  'GA03FLMA',
#  'GA03FLMB',
#  'GA05MOAS',
#  'GI01SUMO',
#  'GI02HYPM',
#  'GI03FLMA',
#  'GI03FLMB',
#  'GI05MOAS',
#  'GP02HYPM',
#  'GP03FLMA',
#  'GP03FLMB',
#  'GP05MOAS',
#  'GS01SUMO',
#  'GS02HYPM',
#  'GS03FLMA',
#  'GS03FLMB',
#  'GS05MOAS',
#  'RS01OSBP',
#  'RS01SBPD',
#  'RS01SBPS',
#  'RS01SHBP',
#  'RS01SHDR',
#  'RS01SLBS',
#  'RS01SUM1',
#  'RS01SUM2',
#  'RS03ASHS',
#  'RS03AXBS',
#  'RS03AXPD',
#  'RS03AXPS',
#  'RS03AXSM',
#  'RS03CCAL',
#  'RS03ECAL',
#  'RS03INT1',
#  'RS03INT2',
#  'SSRSPACC']

# %%
# select CE02SHSM as the site to use for the rest of this example
site = sites[3]

# create a list of nodes available for a particular site
nodes = list_nodes(site)
nodes
# Out:
# ['RIC21', 'RID26', 'RID27', 'SBC11', 'SBD11', 'SBD12']

# %%
# select RID27 (1 of 2 data loggers on the midwater platform) as the node to use for the rest of this example
node = nodes[2]

# create a list of sensors for a particular node
sensors = list_sensors(site, node)
sensors
# Out:
# ['00-DCLENG000',
#  '01-OPTAAD000',
#  '02-FLORTD000',
#  '03-CTDBPC000',
#  '04-DOSTAD000']

# %%
# select the CTD as the sensor to use for the rest of this example
sensor = sensors[3]

# %% [markdown]
# The above steps pedantically construct the reference designator that will be used in a future requests below. There are other sources of this information, such as the [OOI website](https://oceanobservatories.org/), [Data Portal](https://ooinet.oceanobservatories.org/) or [Data Explorer](https://dataexplorer.oceanobservatories.org/) that a user to could work through to construct the reference designator manually. The above methods provide programmitic tools to walk through all of the OOI instruments, of which there are 1398 unique instances (counting engineering and science instruments). It might take awhile to manually search through all those entries. Alternatively, we can programatically find every instance of, for example, the [CTDBP](https://oceanobservatories.org/instrument-class/ctd/) instruments in OOI ...

# %%
# %%time
ctdbp = []
for site in sites:
    nodes = list_nodes(site)
    for node in nodes:
        sensors  = list_sensors(site, node)
        for sensor in sensors:
            if sensor.find('CTDBP') > 0:
                ctdbp.append('-'.join([site, node, sensor]))

ctdbp
# Out:
# CPU times: user 241 ms, sys: 4.14 ms, total: 245 ms
# Wall time: 7.75 s
# ['CE01ISSM-MFD37-03-CTDBPC000',
#  'CE01ISSM-RID16-03-CTDBPC000',
#  'CE01ISSM-SBD17-06-CTDBPC000',
#  'CE02SHBP-LJ01D-06-CTDBPN106',
#  'CE02SHSM-RID27-03-CTDBPC000',
#  'CE04OSBP-LJ01C-06-CTDBPO108',
#  'CE04OSSM-RID27-03-CTDBPC000',
#  'CE06ISSM-MFD37-03-CTDBPC000',
#  'CE06ISSM-RID16-03-CTDBPC000',
#  'CE06ISSM-SBD17-06-CTDBPC000',
#  'CE07SHSM-MFD37-03-CTDBPC000',
#  'CE07SHSM-RID27-03-CTDBPC000',
#  'CE09OSSM-MFD37-03-CTDBPE000',
#  'CE09OSSM-RID27-03-CTDBPC000',
#  'CP01CNSM-MFD37-03-CTDBPD000',
#  'CP01CNSM-RID27-03-CTDBPC000',
#  'CP03ISSM-MFD37-03-CTDBPD000',
#  'CP03ISSM-RID27-03-CTDBPC000',
#  'CP04OSSM-MFD37-03-CTDBPE000',
#  'CP04OSSM-RID27-03-CTDBPC000',
#  'CP10CNSM-MFD37-03-CTDBPC000',
#  'CP10CNSM-RID27-03-CTDBPC000',
#  'CP11NOSM-MFD37-03-CTDBPD000',
#  'CP11NOSM-RID27-03-CTDBPC000',
#  'CP11SOSM-MFD37-03-CTDBPD000',
#  'CP11SOSM-RID27-03-CTDBPC000',
#  'GA01SUMO-RID16-03-CTDBPF000',
#  'GA01SUMO-RII11-02-CTDBPP031',
#  'GA01SUMO-RII11-02-CTDBPP032',
#  'GA01SUMO-RII11-02-CTDBPP033',
#  'GI01SUMO-RID16-03-CTDBPF000',
#  'GI01SUMO-RII11-02-CTDBPP031',
#  'GI01SUMO-RII11-02-CTDBPP032',
#  'GI01SUMO-RII11-02-CTDBPP033',
#  'GS01SUMO-RID16-03-CTDBPF000',
#  'GS01SUMO-RII11-02-CTDBPP031',
#  'GS01SUMO-RII11-02-CTDBPP032',
#  'GS01SUMO-RII11-02-CTDBPP033']

# %% [markdown]
# ... in ~7 seconds. There are 32 of them.
#
# Circling back to the CTD on the Oregon Shelf Surface Mooring midwater platform, or `CE02SHSM-RID27-03-CTDBPC000`, we can use the remaining Sensor Information functions to gather more information about this particular sensor.

# %%
# reset the site, node and sensor to CE02SHSM-RID27-03-CTDBPC000
site = 'CE02SHSM'
node = 'RID27'
sensor = '03-CTDBPC000'

# create a list of the data delivery methods available for this sensor
methods = list_methods(site, node, sensor)
methods
# Out:
# ['recovered_host', 'recovered_inst', 'telemetered']

# %%
# select recovered_host as the data delivery method to use for the rest of this example
method = methods[0]

# create a list of the data streams (aka datasets) available from this sensor and data delivery method
streams = list_streams(site, node, sensor, method)
streams
# Out:
# ['ctdbp_cdef_dcl_instrument_recovered']

# %%
# select the one stream for this data delivery method to use for the rest of this example
stream = streams[0]

# create lists of dictionaries with the available parameters and time ranges covered by each 
# dataset associated with the sensor
metadata = list_metadata(site, node, sensor)
parameters = metadata.pop('parameters')
time_ranges = metadata['times']

# print the parameter dictionaries for the parameters associated with this stream
for p in parameters:
    if p['stream'] == stream:
        pp.pprint(p)
# Out:
# {'fillValue': '-9999999',
#  'particleKey': 'conductivity',
#  'pdId': 'PD1',
#  'shape': 'SCALAR',
#  'stream': 'ctdbp_cdef_dcl_instrument_recovered',
#  'type': 'FLOAT',
#  'units': 'S m-1',
#  'unsigned': False}
# {'fillValue': '-9999999',
#  'particleKey': 'pressure',
#  'pdId': 'PD2',
#  'shape': 'SCALAR',
#  'stream': 'ctdbp_cdef_dcl_instrument_recovered',
#  'type': 'FLOAT',
#  'units': 'dbar',
#  'unsigned': False}
# {'fillValue': '-9999999',
#  'particleKey': 'density',
#  'pdId': 'PD5',
#  'shape': 'FUNCTION',
#  'stream': 'ctdbp_cdef_dcl_instrument_recovered',
#  'type': 'FLOAT',
#  'units': 'kg m-3',
#  'unsigned': False}
# {'fillValue': '-9999999',
#  'particleKey': 'temp',
#  'pdId': 'PD6',
#  'shape': 'SCALAR',
#  'stream': 'ctdbp_cdef_dcl_instrument_recovered',
#  'type': 'FLOAT',
#  'units': 'degrees_Celsius',
#  'unsigned': False}
# {'fillValue': '-9999999',
#  'particleKey': 'time',
#  'pdId': 'PD7',
#  'shape': 'SCALAR',
#  'stream': 'ctdbp_cdef_dcl_instrument_recovered',
#  'type': 'DOUBLE',
#  'units': 'seconds since 1900-01-01',
#  'unsigned': False}
# {'fillValue': '-9999999',
#  'particleKey': 'port_timestamp',
#  'pdId': 'PD10',
#  'shape': 'SCALAR',
#  'stream': 'ctdbp_cdef_dcl_instrument_recovered',
#  'type': 'DOUBLE',
#  'units': 'seconds since 1900-01-01',
#  'unsigned': False}
# {'fillValue': '-9999999',
#  'particleKey': 'driver_timestamp',
#  'pdId': 'PD11',
#  'shape': 'SCALAR',
#  'stream': 'ctdbp_cdef_dcl_instrument_recovered',
#  'type': 'DOUBLE',
#  'units': 'seconds since 1900-01-01',
#  'unsigned': False}
# {'fillValue': '-9999999',
#  'particleKey': 'internal_timestamp',
#  'pdId': 'PD12',
#  'shape': 'SCALAR',
#  'stream': 'ctdbp_cdef_dcl_instrument_recovered',
#  'type': 'DOUBLE',
#  'units': 'seconds since 1900-01-01',
#  'unsigned': False}
# {'fillValue': '-9999999',
#  'particleKey': 'practical_salinity',
#  'pdId': 'PD13',
#  'shape': 'FUNCTION',
#  'stream': 'ctdbp_cdef_dcl_instrument_recovered',
#  'type': 'FLOAT',
#  'units': '1',
#  'unsigned': False}
# {'fillValue': 'empty',
#  'particleKey': 'preferred_timestamp',
#  'pdId': 'PD16',
#  'shape': 'SCALAR',
#  'stream': 'ctdbp_cdef_dcl_instrument_recovered',
#  'type': 'STRING',
#  'units': None,
#  'unsigned': False}
# {'fillValue': 'empty',
#  'particleKey': 'date_time_string',
#  'pdId': 'PD93',
#  'shape': 'SCALAR',
#  'stream': 'ctdbp_cdef_dcl_instrument_recovered',
#  'type': 'STRING',
#  'units': None,
#  'unsigned': False}
# {'fillValue': '-9999',
#  'particleKey': 'ingestion_timestamp',
#  'pdId': 'PD863',
#  'shape': 'SCALAR',
#  'stream': 'ctdbp_cdef_dcl_instrument_recovered',
#  'type': 'DOUBLE',
#  'units': 'seconds since 1900-01-01',
#  'unsigned': False}
# {'fillValue': 'empty',
#  'particleKey': 'dcl_controller_timestamp',
#  'pdId': 'PD2605',
#  'shape': 'SCALAR',
#  'stream': 'ctdbp_cdef_dcl_instrument_recovered',
#  'type': 'STRING',
#  'units': None,
#  'unsigned': False}
# {'fillValue': '-9999999',
#  'particleKey': 'depth',
#  'pdId': 'PD8100',
#  'shape': 'FUNCTION',
#  'stream': 'ctdbp_cdef_dcl_instrument_recovered',
#  'type': 'FLOAT',
#  'units': 'm',
#  'unsigned': False}

# %%
# print the time range for this stream
times = None
for t in time_ranges:
    if t['stream'] == stream:
        pp.pprint(t)
        times = t
# Out:
# {'beginTime': '2015-04-02T20:45:22.170Z',
#  'count': 2100923,
#  'endTime': '2024-10-14T21:29:55.128Z',
#  'method': 'recovered_host',
#  'stream': 'ctdbp_cdef_dcl_instrument_recovered'}

# %% [markdown]
# ## Preload Information

# %%
START = times['beginTime']
STOP = times['endTime']

# %%
# Grab the provenance info and the driver associated with this data stream for this deployment
STREAM = 'ctdbp_cdef_dcl_instrument'
OPTIONS = '?beginDT=' + START + '&endDT=' + STOP + '&limit=2&parameters=7&include_provenance=true&strict_range=true'
r = requests.get(BASE_URL + SENSOR_URL + site + '/' +
                    node + '/' + sensor + '/' + method + '/'+ stream + OPTIONS, auth=(AUTH[0], AUTH[2]))
data = r.json()
print(json.dumps(data, indent=2))

# note this will fail if the system does not have any data, we want to know that so will need to code for failures
# Out:
# {
#   "data": [
#     {
#       "pk": {
#         "node": "RID27",
#         "stream": "ctdbp_cdef_dcl_instrument_recovered",
#         "subsite": "CE02SHSM",
#         "deployment": 1,
#         "time": 3636996322.17,
#         "sensor": "03-CTDBPC000",
#         "method": "recovered_host"
#       },
#       "provenance": "9d1105d1-58d5-48a1-9c2d-bb5dc281b2ab",
#       "time": 3636996322.17
#     },
#     {
#       "pk": {
#         "node": "RID27",
#         "stream": "ctdbp_cdef_dcl_instrument_recovered",
#         "subsite": "CE02SHSM",
#         "deployment": 18,
#         "time": 3937930195.1280003,
#         "sensor": "03-CTDBPC000",
#         "method": "recovered_host"
#       },
#       "provenance": "3212a27f-8c0e-4c21-853d-5f208e48cd2a",
#       "time": 3937930195.1280003
#     }
#   ],
#   "provenance": {
#     "3212a27f-8c0e-4c21-853d-5f208e48cd2a": {
#       "file_name": "/omc_data/whoi/OMC/CE02SHSM/R00018/cg_data/dcl27/ctdbp/20241014.ctdbp.log",
#       "parser_name": "mi.dataset.driver.ctdbp_cdef.dcl.ctdbp_cdef_dcl_recovered_driver",
#       "parser_version": "15.7.1"
#     },
#     "9d1105d1-58d5-48a1-9c2d-bb5dc281b2ab": {
#       "file_name": "/omc_data/whoi/OMC/CE02SHSM/R00001/cg_data/dcl27/ctdbp/20150402.ctdbp.log",
#       "parser_name": "mi.dataset.driver.ctdbp_cdef.dcl.ctdbp_cdef_dcl_recovered_driver",
#       "parser_version": "15.7.1"
#     }
#   },
#   "instrument_provenance": {
#     "CE02SHSM-RID27-03-CTDBPC000": [
#       {
#         "@class": ".XDeployment",
#         "eventId": 1357,
#         "editPhase": "OPERATIONAL",
#         "eventName": "CE02SHSM-RID27-03-CTDBPC000",
#         "eventType": "DEPLOYMENT",
#         "referenceDesignator": "CE02SHSM-RID27-03-CTDBPC000",
#         "deploymentNumber": 1,
#         "versionNumber": 1,
#         "inductiveId": null,
#         "assetUid": null,
#         "dataSource": "Load from [CE02SHSM_Deploy.csv]",
#         "lastModifiedTimestamp": 1744314836760,
#         "tense": "UNKNOWN",
#         "ingestInfo": [],
#         "notes": null,
#         "mooring": {
#           "@class": ".XMooring",
#           "assetId": 1135,
#           "assetType": "Mooring",
#           "dataSource": "BulkLoad from [platform_bulk_load-AssetRecord.csv]",
#           "deliveryDate": null,
#           "deliveryOrderNumber": null,
#           "depthRating": null,
#           "description": "Coastal Endurance Oregon Shelf Surface Mooring",
#           "editPhase": "OPERATIONAL",
#           "events": [],
#           "firmwareVersion": null,
#           "institutionPropertyNumber": null,
#           "institutionPurchaseOrderNumber": null,
#           "lastModifiedTimestamp": 1744314766067,
#           "location": null,
#           "manufacturer": "WHOI",
#           "mobile": false,
#           "modelNumber": "CE02SHSM",
#           "name": "CE02SHSM-00001",
#           "notes": null,
#           "ooiPartNumber": null,
#           "ooiPropertyNumber": null,
#           "ooiSerialNumber": null,
#           "owner": "Oregon State University",
#           "physicalInfo": {
#             "height": -1.0,
#             "length": -1.0,
#             "weight": -1.0,
#             "width": -1.0
#           },
#           "powerRequirements": null,
#           "purchaseDate": null,
#           "purchasePrice": null,
#           "remoteResources": [],
#           "serialNumber": "CE02SHSM-00001",
#           "shelfLifeExpirationDate": null,
#           "softwareVersion": null,
#           "uid": "CGMCE-02SHSM-00001"
#         },
#         "node": null,
#         "eventStartTime": 1428005700000,
#         "eventStopTime": 1442908080000,
#         "waterDepth": 80.0,
#         "location": {
#           "depth": 7.0,
#           "latitude": 44.63833,
#           "longitude": -124.30388,
#           "orbitRadius": 250.0,
#           "location": [
#             -124.30388,
#             44.63833
#           ]
#         },
#         "deployedBy": null,
#         "deployCruiseInfo": {
#           "@class": ".CruiseInfo",
#           "assetUid": null,
#           "cruiseIdentifier": null,
#           "dataSource": "Load from [CruiseInformation.csv]",
#           "editPhase": "OPERATIONAL",
#           "eventId": 27,
#           "eventName": "OC1503D",
#           "eventStartTime": 1427932800000,
#           "eventStopTime": 1428883199000,
#           "eventType": "CRUISE_INFO",
#           "lastModifiedTimestamp": 1744314614949,
#           "notes": null,
#           "shipName": "Oceanus",
#           "tense": "UNKNOWN",
#           "uniqueCruiseIdentifier": "OC1503D"
#         },
#         "recoveredBy": null,
#         "recoverCruiseInfo": {
#           "@class": ".CruiseInfo",
#           "assetUid": null,
#           "cruiseIdentifier": null,
#           "dataSource": "Load from [CruiseInformation.csv]",
#           "editPhase": "OPERATIONAL",
#           "eventId": 43,
#           "eventName": "TN330",
#           "eventStartTime": 1442880000000,
#           "eventStopTime": 1443398399000,
#           "eventType": "CRUISE_INFO",
#           "lastModifiedTimestamp": 1744314615003,
#           "notes": null,
#           "shipName": "Thomas G. Thompson",
#           "tense": "UNKNOWN",
#           "uniqueCruiseIdentifier": "TN330"
#         },
#         "sensor": {
#           "@class": ".XInstrument",
#           "assetId": 1692,
#           "assetType": "Sensor",
#           "dataSource": "BulkLoad from [sensor_bulk_load-AssetRecord.csv]",
#           "deliveryDate": 1393200000000,
#           "deliveryOrderNumber": null,
#           "depthRating": null,
#           "description": "CTD Pumped: CTDBP Series C",
#           "editPhase": "OPERATIONAL",
#           "events": [],
#           "firmwareVersion": null,
#           "institutionPropertyNumber": null,
#           "institutionPurchaseOrderNumber": null,
#           "lastModifiedTimestamp": 1744314805494,
#           "location": null,
#           "manufacturer": "Sea-Bird Electronics",
#           "mobile": false,
#           "modelNumber": "SBE 16plus V2",
#           "name": "16-50012",
#           "notes": null,
#           "ooiPartNumber": null,
#           "ooiPropertyNumber": null,
#           "ooiSerialNumber": null,
#           "owner": null,
#           "physicalInfo": {
#             "height": -1.0,
#             "length": -1.0,
#             "weight": -1.0,
#             "width": -1.0
#           },
#           "powerRequirements": null,
#           "purchaseDate": 1393200000000,
#           "purchasePrice": 11500.0,
#           "remoteResources": [],
#           "serialNumber": "16-50012",
#           "shelfLifeExpirationDate": null,
#           "softwareVersion": null,
#           "uid": "CGINS-CTDBPC-50012",
#           "calibration": [
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32158,
#                   "eventName": "CC_i",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -0.0002672917
#                 }
#               ],
#               "name": "CC_i"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32160,
#                   "eventName": "CC_h",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 0.139731
#                 }
#               ],
#               "name": "CC_h"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32162,
#                   "eventName": "CC_g",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -0.9794006
#                 }
#               ],
#               "name": "CC_g"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32164,
#                   "eventName": "CC_pa0",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -0.146232899
#                 }
#               ],
#               "name": "CC_pa0"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32166,
#                   "eventName": "CC_pa2",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -5.95646353e-12
#                 }
#               ],
#               "name": "CC_pa2"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32168,
#                   "eventName": "CC_pa1",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 0.000487158914
#                 }
#               ],
#               "name": "CC_pa1"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32170,
#                   "eventName": "CC_ptca1",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -18.3216153
#                 }
#               ],
#               "name": "CC_ptca1"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32172,
#                   "eventName": "CC_ptcb2",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 0.0
#                 }
#               ],
#               "name": "CC_ptcb2"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32174,
#                   "eventName": "CC_ptca0",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 524875.411
#                 }
#               ],
#               "name": "CC_ptca0"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32176,
#                   "eventName": "CC_ptcb1",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 0.000325
#                 }
#               ],
#               "name": "CC_ptcb1"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32178,
#                   "eventName": "CC_ptca2",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 0.179273715
#                 }
#               ],
#               "name": "CC_ptca2"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32180,
#                   "eventName": "CC_ptcb0",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 25.100625
#                 }
#               ],
#               "name": "CC_ptcb0"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32182,
#                   "eventName": "CC_a0",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 0.001254062
#                 }
#               ],
#               "name": "CC_a0"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32184,
#                   "eventName": "CC_ptempa2",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -0.355813045
#                 }
#               ],
#               "name": "CC_ptempa2"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32186,
#                   "eventName": "CC_a1",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 0.0002748597
#                 }
#               ],
#               "name": "CC_a1"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32188,
#                   "eventName": "CC_a2",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -1.176268e-06
#                 }
#               ],
#               "name": "CC_a2"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32190,
#                   "eventName": "CC_ptempa1",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 53.6581701
#                 }
#               ],
#               "name": "CC_ptempa1"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32192,
#                   "eventName": "CC_a3",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 1.840381e-07
#                 }
#               ],
#               "name": "CC_a3"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32194,
#                   "eventName": "CC_ptempa0",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -59.2784052
#                 }
#               ],
#               "name": "CC_ptempa0"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32196,
#                   "eventName": "CC_cpcor",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -9.57e-08
#                 }
#               ],
#               "name": "CC_cpcor"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32198,
#                   "eventName": "CC_ctcor",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 3.25e-06
#                 }
#               ],
#               "name": "CC_ctcor"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-50012",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-50012__20140220.csv",
#                   "eventId": 32200,
#                   "eventName": "CC_j",
#                   "eventStartTime": 1392854400000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314941448,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 4.001858e-05
#                 }
#               ],
#               "name": "CC_j"
#             }
#           ]
#         }
#       },
#       {
#         "@class": ".XDeployment",
#         "eventId": 1877,
#         "editPhase": "OPERATIONAL",
#         "eventName": "CE02SHSM-RID27-03-CTDBPC000",
#         "eventType": "DEPLOYMENT",
#         "referenceDesignator": "CE02SHSM-RID27-03-CTDBPC000",
#         "deploymentNumber": 18,
#         "versionNumber": 1,
#         "inductiveId": null,
#         "assetUid": null,
#         "dataSource": "Load from [CE02SHSM_Deploy.csv]",
#         "lastModifiedTimestamp": 1744314838707,
#         "tense": "UNKNOWN",
#         "ingestInfo": [],
#         "notes": null,
#         "mooring": {
#           "@class": ".XMooring",
#           "assetId": 1113,
#           "assetType": "Mooring",
#           "dataSource": "BulkLoad from [platform_bulk_load-AssetRecord.csv]",
#           "deliveryDate": null,
#           "deliveryOrderNumber": null,
#           "depthRating": null,
#           "description": "Coastal Endurance Oregon Shelf Surface Mooring",
#           "editPhase": "OPERATIONAL",
#           "events": [],
#           "firmwareVersion": null,
#           "institutionPropertyNumber": null,
#           "institutionPurchaseOrderNumber": null,
#           "lastModifiedTimestamp": 1744314765999,
#           "location": null,
#           "manufacturer": "WHOI",
#           "mobile": false,
#           "modelNumber": "CE02SHSM",
#           "name": "CE02SHSM-00018",
#           "notes": null,
#           "ooiPartNumber": null,
#           "ooiPropertyNumber": null,
#           "ooiSerialNumber": null,
#           "owner": "Oregon State University",
#           "physicalInfo": {
#             "height": -1.0,
#             "length": -1.0,
#             "weight": -1.0,
#             "width": -1.0
#           },
#           "powerRequirements": null,
#           "purchaseDate": null,
#           "purchasePrice": null,
#           "remoteResources": [],
#           "serialNumber": "CE02SHSM-00018",
#           "shelfLifeExpirationDate": null,
#           "softwareVersion": null,
#           "uid": "CGMCE-02SHSM-00018"
#         },
#         "node": null,
#         "eventStartTime": 1712528700000,
#         "eventStopTime": 1728945660000,
#         "waterDepth": 80.0,
#         "location": {
#           "depth": 7.0,
#           "latitude": 44.63532,
#           "longitude": -124.3032,
#           "orbitRadius": 250.0,
#           "location": [
#             -124.3032,
#             44.63532
#           ]
#         },
#         "deployedBy": null,
#         "deployCruiseInfo": {
#           "@class": ".CruiseInfo",
#           "assetUid": null,
#           "cruiseIdentifier": null,
#           "dataSource": "Load from [CruiseInformation.csv]",
#           "editPhase": "OPERATIONAL",
#           "eventId": 341,
#           "eventName": "SKQ202405S",
#           "eventStartTime": 1711753200000,
#           "eventStopTime": 1712880000000,
#           "eventType": "CRUISE_INFO",
#           "lastModifiedTimestamp": 1744314615644,
#           "notes": null,
#           "shipName": "Sikuliaq",
#           "tense": "UNKNOWN",
#           "uniqueCruiseIdentifier": "SKQ202405S"
#         },
#         "recoveredBy": null,
#         "recoverCruiseInfo": {
#           "@class": ".CruiseInfo",
#           "assetUid": null,
#           "cruiseIdentifier": null,
#           "dataSource": "Load from [CruiseInformation.csv]",
#           "editPhase": "OPERATIONAL",
#           "eventId": 364,
#           "eventName": "SKQ202415S",
#           "eventStartTime": 1728074400000,
#           "eventStopTime": 1729287000000,
#           "eventType": "CRUISE_INFO",
#           "lastModifiedTimestamp": 1744314615687,
#           "notes": null,
#           "shipName": "Sikuliaq",
#           "tense": "UNKNOWN",
#           "uniqueCruiseIdentifier": "SKQ202415S"
#         },
#         "sensor": {
#           "@class": ".XInstrument",
#           "assetId": 3975,
#           "assetType": "Sensor",
#           "dataSource": "BulkLoad from [sensor_bulk_load-AssetRecord.csv]",
#           "deliveryDate": 1356566400000,
#           "deliveryOrderNumber": null,
#           "depthRating": null,
#           "description": "CTD Pumped: CTDBP Series C",
#           "editPhase": "OPERATIONAL",
#           "events": [],
#           "firmwareVersion": null,
#           "institutionPropertyNumber": null,
#           "institutionPurchaseOrderNumber": null,
#           "lastModifiedTimestamp": 1744314812865,
#           "location": null,
#           "manufacturer": "Sea-Bird Electronics",
#           "mobile": false,
#           "modelNumber": "SBE 16plus V2",
#           "name": "16-7243",
#           "notes": null,
#           "ooiPartNumber": null,
#           "ooiPropertyNumber": null,
#           "ooiSerialNumber": null,
#           "owner": null,
#           "physicalInfo": {
#             "height": -1.0,
#             "length": -1.0,
#             "weight": -1.0,
#             "width": -1.0
#           },
#           "powerRequirements": null,
#           "purchaseDate": 1356566400000,
#           "purchasePrice": 11150.0,
#           "remoteResources": [],
#           "serialNumber": "16-7243",
#           "shelfLifeExpirationDate": null,
#           "softwareVersion": null,
#           "uid": "CGINS-CTDBPC-07243",
#           "calibration": [
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30419,
#                   "eventName": "CC_i",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -0.0003736453
#                 }
#               ],
#               "name": "CC_i"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30420,
#                   "eventName": "CC_h",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 0.157056
#                 }
#               ],
#               "name": "CC_h"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30421,
#                   "eventName": "CC_g",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -0.9941896000000001
#                 }
#               ],
#               "name": "CC_g"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30422,
#                   "eventName": "CC_pa0",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -0.0234367
#                 }
#               ],
#               "name": "CC_pa0"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30423,
#                   "eventName": "CC_pa2",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -4.241994999999999e-12
#                 }
#               ],
#               "name": "CC_pa2"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30424,
#                   "eventName": "CC_pa1",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 0.0004881439
#                 }
#               ],
#               "name": "CC_pa1"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30425,
#                   "eventName": "CC_ptca1",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -3.504476
#                 }
#               ],
#               "name": "CC_ptca1"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30426,
#                   "eventName": "CC_ptcb2",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 0.0
#                 }
#               ],
#               "name": "CC_ptcb2"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30427,
#                   "eventName": "CC_ptca0",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 525542.3
#                 }
#               ],
#               "name": "CC_ptca0"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30428,
#                   "eventName": "CC_ptcb1",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 0.000675
#                 }
#               ],
#               "name": "CC_ptcb1"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30429,
#                   "eventName": "CC_ptca2",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 0.06955997
#                 }
#               ],
#               "name": "CC_ptca2"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30430,
#                   "eventName": "CC_ptcb0",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 25.06838
#                 }
#               ],
#               "name": "CC_ptcb0"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": "date in filename comes from latest sensor caldate within QCT cap file",
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30431,
#                   "eventName": "CC_a0",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 0.001265448
#                 }
#               ],
#               "name": "CC_a0"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30432,
#                   "eventName": "CC_ptempa2",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -0.4679394
#                 }
#               ],
#               "name": "CC_ptempa2"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30433,
#                   "eventName": "CC_a1",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 0.0002704579
#                 }
#               ],
#               "name": "CC_a1"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30434,
#                   "eventName": "CC_a2",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -6.813988e-07
#                 }
#               ],
#               "name": "CC_a2"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30435,
#                   "eventName": "CC_ptempa1",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 52.8005
#                 }
#               ],
#               "name": "CC_ptempa1"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30436,
#                   "eventName": "CC_a3",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 1.631968e-07
#                 }
#               ],
#               "name": "CC_a3"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30437,
#                   "eventName": "CC_ptempa0",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -65.76881
#                 }
#               ],
#               "name": "CC_ptempa0"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30438,
#                   "eventName": "CC_cpcor",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": -9.57e-08
#                 }
#               ],
#               "name": "CC_cpcor"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30439,
#                   "eventName": "CC_ctcor",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 3.25e-06
#                 }
#               ],
#               "name": "CC_ctcor"
#             },
#             {
#               "@class": ".XCalibration",
#               "calData": [
#                 {
#                   "@class": ".XCalibrationData",
#                   "assetUid": "CGINS-CTDBPC-07243",
#                   "comments": null,
#                   "dataSource": "CGINS-CTDBPC-07243__20240117.csv",
#                   "eventId": 30440,
#                   "eventName": "CC_j",
#                   "eventStartTime": 1705449600000,
#                   "eventStopTime": null,
#                   "eventType": "CALIBRATION_DATA",
#                   "lastModifiedTimestamp": 1744314936531,
#                   "notes": null,
#                   "tense": "UNKNOWN",
#                   "value": 5.303048000000001e-05
#                 }
#               ],
#               "name": "CC_j"
#             }
#           ]
#         }
#       }
#     ]
#   },
#   "computed_provenance": {
#     "errors": [],
#     "calculations": {
#       "feb8604b-b042-4f1b-b162-b655edb2d8e5": {
#         "function_owner": "ion_functions.data.ctd_functions",
#         "arguments": {
#           "p": {
#             "time_end": 3636996322.17,
#             "parameter_id": 2,
#             "time_start": 3636996322.17,
#             "name": "pressure",
#             "data_product_identifier": "PRESWAT_L1",
#             "interpolated": false,
#             "deployments": [
#               1
#             ],
#             "source": "CE02SHSM|RID27|03-CTDBPC000|recovered_host|ctdbp_cdef_dcl_instrument_recovered",
#             "time_startDT": "2015-04-02T20:45:22.170000",
#             "type": "parameter",
#             "time_endDT": "2015-04-02T20:45:22.170000"
#           },
#           "c": {
#             "time_end": 3636996322.17,
#             "parameter_id": 1,
#             "time_start": 3636996322.17,
#             "name": "conductivity",
#             "data_product_identifier": "CONDWAT_L1",
#             "interpolated": false,
#             "deployments": [
#               1
#             ],
#             "source": "CE02SHSM|RID27|03-CTDBPC000|recovered_host|ctdbp_cdef_dcl_instrument_recovered",
#             "time_startDT": "2015-04-02T20:45:22.170000",
#             "type": "parameter",
#             "time_endDT": "2015-04-02T20:45:22.170000"
#           },
#           "t": {
#             "time_end": 3636996322.17,
#             "parameter_id": 6,
#             "time_start": 3636996322.17,
#             "name": "temp",
#             "data_product_identifier": "TEMPWAT_L1",
#             "interpolated": false,
#             "deployments": [
#               1
#             ],
#             "source": "CE02SHSM|RID27|03-CTDBPC000|recovered_host|ctdbp_cdef_dcl_instrument_recovered",
#             "time_startDT": "2015-04-02T20:45:22.170000",
#             "type": "parameter",
#             "time_endDT": "2015-04-02T20:45:22.170000"
#           },
#           "time_source": {
#             "beginDT": "2015-04-02T20:45:22.170000",
#             "begin": 3636996322.17,
#             "end": 3636996322.17,
#             "endDT": "2015-04-02T20:45:22.170000"
#           }
#         },
#         "function_type": "PythonFunction",
#         "argument_list": [
#           "p",
#           "c",
#           "t"
#         ],
#         "function_id": 26,
#         "function_version": "2.1.0",
#         "function_name": "ctd_pracsal"
#       },
#       "237c3aee-3158-41d5-a89b-b746d2e87272": {
#         "function_owner": "ion_functions.data.ctd_functions",
#         "arguments": {
#           "p": {
#             "time_end": 3937930195.1280003,
#             "parameter_id": 2,
#             "time_start": 3937930195.1280003,
#             "name": "pressure",
#             "data_product_identifier": "PRESWAT_L1",
#             "interpolated": false,
#             "deployments": [
#               18
#             ],
#             "source": "CE02SHSM|RID27|03-CTDBPC000|recovered_host|ctdbp_cdef_dcl_instrument_recovered",
#             "time_startDT": "2024-10-14T21:29:55.128000",
#             "type": "parameter",
#             "time_endDT": "2024-10-14T21:29:55.128000"
#           },
#           "c": {
#             "time_end": 3937930195.1280003,
#             "parameter_id": 1,
#             "time_start": 3937930195.1280003,
#             "name": "conductivity",
#             "data_product_identifier": "CONDWAT_L1",
#             "interpolated": false,
#             "deployments": [
#               18
#             ],
#             "source": "CE02SHSM|RID27|03-CTDBPC000|recovered_host|ctdbp_cdef_dcl_instrument_recovered",
#             "time_startDT": "2024-10-14T21:29:55.128000",
#             "type": "parameter",
#             "time_endDT": "2024-10-14T21:29:55.128000"
#           },
#           "t": {
#             "time_end": 3937930195.1280003,
#             "parameter_id": 6,
#             "time_start": 3937930195.1280003,
#             "name": "temp",
#             "data_product_identifier": "TEMPWAT_L1",
#             "interpolated": false,
#             "deployments": [
#               18
#             ],
#             "source": "CE02SHSM|RID27|03-CTDBPC000|recovered_host|ctdbp_cdef_dcl_instrument_recovered",
#             "time_startDT": "2024-10-14T21:29:55.128000",
#             "type": "parameter",
#             "time_endDT": "2024-10-14T21:29:55.128000"
#           },
#           "time_source": {
#             "beginDT": "2024-10-14T21:29:55.128000",
#             "begin": 3937930195.1280003,
#             "end": 3937930195.1280003,
#             "endDT": "2024-10-14T21:29:55.128000"
#           }
#         },
#         "function_type": "PythonFunction",
#         "argument_list": [
#           "p",
#           "c",
#           "t"
#         ],
#         "function_id": 26,
#         "function_version": "2.1.0",
#         "function_name": "ctd_pracsal"
#       },
#       "46332963-0a5e-49ec-9c19-fcbe65f6f614": {
#         "function_owner": "ion_functions.data.ctd_functions",
#         "arguments": {
#           "SP": {
#             "time_end": 3636996322.17,
#             "parameter_id": 13,
#             "time_start": 3636996322.17,
#             "name": "practical_salinity",
#             "data_product_identifier": "PRACSAL_L2",
#             "interpolated": false,
#             "deployments": [
#               1
#             ],
#             "source": "CE02SHSM|RID27|03-CTDBPC000|recovered_host|ctdbp_cdef_dcl_instrument_recovered",
#             "time_startDT": "2015-04-02T20:45:22.170000",
#             "type": "parameter",
#             "time_endDT": "2015-04-02T20:45:22.170000"
#           },
#           "lon": {
#             "data_begin": 3636996322.17,
#             "beginDT": "2015-04-02T20:45:22.170000",
#             "endDT": "2015-04-02T20:45:22.170000",
#             "data_end": 3636996322.17,
#             "sources": -124.30388,
#             "type": "CC"
#           },
#           "time_source": {
#             "beginDT": "2015-04-02T20:45:22.170000",
#             "begin": 3636996322.17,
#             "end": 3636996322.17,
#             "endDT": "2015-04-02T20:45:22.170000"
#           },
#           "p": {
#             "time_end": 3636996322.17,
#             "parameter_id": 2,
#             "time_start": 3636996322.17,
#             "name": "pressure",
#             "data_product_identifier": "PRESWAT_L1",
#             "interpolated": false,
#             "deployments": [
#               1
#             ],
#             "source": "CE02SHSM|RID27|03-CTDBPC000|recovered_host|ctdbp_cdef_dcl_instrument_recovered",
#             "time_startDT": "2015-04-02T20:45:22.170000",
#             "type": "parameter",
#             "time_endDT": "2015-04-02T20:45:22.170000"
#           },
#           "t": {
#             "time_end": 3636996322.17,
#             "parameter_id": 6,
#             "time_start": 3636996322.17,
#             "name": "temp",
#             "data_product_identifier": "TEMPWAT_L1",
#             "interpolated": false,
#             "deployments": [
#               1
#             ],
#             "source": "CE02SHSM|RID27|03-CTDBPC000|recovered_host|ctdbp_cdef_dcl_instrument_recovered",
#             "time_startDT": "2015-04-02T20:45:22.170000",
#             "type": "parameter",
#             "time_endDT": "2015-04-02T20:45:22.170000"
#           },
#           "lat": {
#             "data_begin": 3636996322.17,
#             "beginDT": "2015-04-02T20:45:22.170000",
#             "endDT": "2015-04-02T20:45:22.170000",
#             "data_end": 3636996322.17,
#             "sources": 44.63833,
#             "type": "CC"
#           }
#         },
#         "function_type": "PythonFunction",
#         "argument_list": [
#           "lat",
#           "p",
#           "SP",
#           "lon",
#           "t"
#         ],
#         "function_id": 27,
#         "function_version": "2.1.0",
#         "function_name": "ctd_density"
#       },
#       "36bce854-27ff-4999-abc9-f768895f2e71": {
#         "function_owner": "ion_functions.data.adcp_functions",
#         "arguments": {
#           "latitude": {
#             "data_begin": 3636996322.17,
#             "beginDT": "2015-04-02T20:45:22.170000",
#             "endDT": "2015-04-02T20:45:22.170000",
#             "data_end": 3636996322.17,
#             "sources": 44.63833,
#             "type": "CC"
#           },
#           "pressure": {
#             "time_end": 3636996322.17,
#             "parameter_id": 2,
#             "time_start": 3636996322.17,
#             "name": "pressure",
#             "data_product_identifier": "PRESWAT_L1",
#             "interpolated": false,
#             "deployments": [
#               1
#             ],
#             "source": "CE02SHSM|RID27|03-CTDBPC000|recovered_host|ctdbp_cdef_dcl_instrument_recovered",
#             "time_startDT": "2015-04-02T20:45:22.170000",
#             "type": "parameter",
#             "time_endDT": "2015-04-02T20:45:22.170000"
#           },
#           "time_source": {
#             "beginDT": "2015-04-02T20:45:22.170000",
#             "begin": 3636996322.17,
#             "end": 3636996322.17,
#             "endDT": "2015-04-02T20:45:22.170000"
#           },
#           "pressure_scale_factor": {
#             "constant": 1
#           }
#         },
#         "function_type": "PythonFunction",
#         "argument_list": [
#           "latitude",
#           "pressure",
#           "pressure_scale_factor"
#         ],
#         "function_id": 217,
#         "function_version": "2.1.0",
#         "function_name": "depth_from_pressure_dbar"
#       },
#       "43e30d7c-3033-4623-a741-95882d90b655": {
#         "function_owner": "ion_functions.data.ctd_functions",
#         "arguments": {
#           "SP": {
#             "time_end": 3937930195.1280003,
#             "parameter_id": 13,
#             "time_start": 3937930195.1280003,
#             "name": "practical_salinity",
#             "data_product_identifier": "PRACSAL_L2",
#             "interpolated": false,
#             "deployments": [
#               18
#             ],
#             "source": "CE02SHSM|RID27|03-CTDBPC000|recovered_host|ctdbp_cdef_dcl_instrument_recovered",
#             "time_startDT": "2024-10-14T21:29:55.128000",
#             "type": "parameter",
#             "time_endDT": "2024-10-14T21:29:55.128000"
#           },
#           "lon": {
#             "data_begin": 3937930195.1280003,
#             "beginDT": "2024-10-14T21:29:55.128000",
#             "endDT": "2024-10-14T21:29:55.128000",
#             "data_end": 3937930195.1280003,
#             "sources": -124.3032,
#             "type": "CC"
#           },
#           "time_source": {
#             "beginDT": "2024-10-14T21:29:55.128000",
#             "begin": 3937930195.1280003,
#             "end": 3937930195.1280003,
#             "endDT": "2024-10-14T21:29:55.128000"
#           },
#           "p": {
#             "time_end": 3937930195.1280003,
#             "parameter_id": 2,
#             "time_start": 3937930195.1280003,
#             "name": "pressure",
#             "data_product_identifier": "PRESWAT_L1",
#             "interpolated": false,
#             "deployments": [
#               18
#             ],
#             "source": "CE02SHSM|RID27|03-CTDBPC000|recovered_host|ctdbp_cdef_dcl_instrument_recovered",
#             "time_startDT": "2024-10-14T21:29:55.128000",
#             "type": "parameter",
#             "time_endDT": "2024-10-14T21:29:55.128000"
#           },
#           "t": {
#             "time_end": 3937930195.1280003,
#             "parameter_id": 6,
#             "time_start": 3937930195.1280003,
#             "name": "temp",
#             "data_product_identifier": "TEMPWAT_L1",
#             "interpolated": false,
#             "deployments": [
#               18
#             ],
#             "source": "CE02SHSM|RID27|03-CTDBPC000|recovered_host|ctdbp_cdef_dcl_instrument_recovered",
#             "time_startDT": "2024-10-14T21:29:55.128000",
#             "type": "parameter",
#             "time_endDT": "2024-10-14T21:29:55.128000"
#           },
#           "lat": {
#             "data_begin": 3937930195.1280003,
#             "beginDT": "2024-10-14T21:29:55.128000",
#             "endDT": "2024-10-14T21:29:55.128000",
#             "data_end": 3937930195.1280003,
#             "sources": 44.63532,
#             "type": "CC"
#           }
#         },
#         "function_type": "PythonFunction",
#         "argument_list": [
#           "lat",
#           "p",
#           "SP",
#           "lon",
#           "t"
#         ],
#         "function_id": 27,
#         "function_version": "2.1.0",
#         "function_name": "ctd_density"
#       },
#       "bab8dd83-b29c-412e-8080-8c3b22b8da3c": {
#         "function_owner": "ion_functions.data.adcp_functions",
#         "arguments": {
#           "latitude": {
#             "data_begin": 3937930195.1280003,
#             "beginDT": "2024-10-14T21:29:55.128000",
#             "endDT": "2024-10-14T21:29:55.128000",
#             "data_end": 3937930195.1280003,
#             "sources": 44.63532,
#             "type": "CC"
#           },
#           "pressure": {
#             "time_end": 3937930195.1280003,
#             "parameter_id": 2,
#             "time_start": 3937930195.1280003,
#             "name": "pressure",
#             "data_product_identifier": "PRESWAT_L1",
#             "interpolated": false,
#             "deployments": [
#               18
#             ],
#             "source": "CE02SHSM|RID27|03-CTDBPC000|recovered_host|ctdbp_cdef_dcl_instrument_recovered",
#             "time_startDT": "2024-10-14T21:29:55.128000",
#             "type": "parameter",
#             "time_endDT": "2024-10-14T21:29:55.128000"
#           },
#           "time_source": {
#             "beginDT": "2024-10-14T21:29:55.128000",
#             "begin": 3937930195.1280003,
#             "end": 3937930195.1280003,
#             "endDT": "2024-10-14T21:29:55.128000"
#           },
#           "pressure_scale_factor": {
#             "constant": 1
#           }
#         },
#         "function_type": "PythonFunction",
#         "argument_list": [
#           "latitude",
#           "pressure",
#           "pressure_scale_factor"
#         ],
#         "function_id": 217,
#         "function_version": "2.1.0",
#         "function_name": "depth_from_pressure_dbar"
#       }
#     },
#     "parameters": {
#       "sea_water_density": [
#         "46332963-0a5e-49ec-9c19-fcbe65f6f614",
#         "43e30d7c-3033-4623-a741-95882d90b655"
#       ],
#       "depth": [
#         "36bce854-27ff-4999-abc9-f768895f2e71",
#         "bab8dd83-b29c-412e-8080-8c3b22b8da3c"
#       ],
#       "sea_water_practical_salinity": [
#         "feb8604b-b042-4f1b-b162-b655edb2d8e5",
#         "237c3aee-3158-41d5-a89b-b746d2e87272"
#       ]
#     }
#   },
#   "query_parameter_provenance": {
#     "query_type": "JSON",
#     "query_uuid": "7dc2b3a7-b4ae-4014-975a-088f50a3532d",
#     "begin": 3636996322.17,
#     "beginDT": "2015-04-02T20:45:22.170000",
#     "end": 3937930195.1280003,
#     "endDT": "2024-10-14T21:29:55.128000",
#     "limit": 2,
#     "requested_stream": "CE02SHSM-RID27-03-CTDBPC000-recovered_host-ctdbp_cdef_dcl_instrument_recovered",
#     "include_provenance": true,
#     "include_annotations": false,
#     "strict_range": true
#   },
#   "provenance_messages": [],
#   "requestUUID": "7dc2b3a7-b4ae-4014-975a-088f50a3532d"
# }

# %%
# determine the driver used to parse the data and the source of the data
provenance = data['provenance']
driver = [provenance[key]['parser_name'] for key in provenance.keys()][0].encode('ascii', 'ignore')
infile = [provenance[key]['file_name'] for key in provenance.keys()][0].encode('ascii', 'ignore')

# %%
print(driver, infile)
# Out:
# b'mi.dataset.driver.ctdbp_cdef.dcl.ctdbp_cdef_dcl_recovered_driver' b'/omc_data/whoi/OMC/CE02SHSM/R00018/cg_data/dcl27/ctdbp/20241014.ctdbp.log'
