# %%
# %matplotlib inline

# load the different libraries and modules needed for the analysis
import csv
import io
import numpy as np
import os
import pandas as pd
import re
import xarray as xr

from ooi_data_explorations.common import get_vocabulary, load_kdata
from ooi_data_explorations.uncabled.process_optaa import optaa_datalogger

from matplotlib import pyplot as plt

# %%
import os

# %%
sorted(os.listdir("/home/jovyan/ooi/kdata/CP03ISSM-RID27-01-OPTAAD000-recovered_host-optaa_dj_dcl_instrument_recovered/"))
# Out:
# ['CP03ISSM-RID27-01-OPTAAD000-recovered_host-optaa_dj_dcl_instrument_recovered_annotations.json',
#  'deployment0002_CP03ISSM-RID27-01-OPTAAD000-recovered_host-optaa_dj_dcl_instrument_recovered.ncml',
#  'deployment0002_CP03ISSM-RID27-01-OPTAAD000-recovered_host-optaa_dj_dcl_instrument_recovered_20150509T010017-20150615T230200.997000.nc',
#  'deployment0002_CP03ISSM-RID27-01-OPTAAD000-recovered_host-optaa_dj_dcl_instrument_recovered_20150616T000017-20150911T230201.242000.nc',
#  'deployment0002_CP03ISSM-RID27-01-OPTAAD000-recovered_host-optaa_dj_dcl_instrument_recovered_20150912T000019-20151021T180202.998000.nc',
#  'deployment0002_CP03ISSM-RID27-01-OPTAAD000-recovered_host-optaa_dj_dcl_instrument_recovered_aggregate_provenance.json',
#  'deployment0002_CP03ISSM-RID27-03-CTDBPC000-recovered_host-ctdbp_cdef_dcl_instrument_recovered.ncml',
# ...

# %%
check = xr.open_dataset("/home/jovyan/ooi/kdata/CP03ISSM-RID27-01-OPTAAD000-recovered_host-optaa_dj_dcl_instrument_recovered/deployment0012_CP03ISSM-RID27-01-OPTAAD000-recovered_host-optaa_dj_dcl_instrument_recovered_20201031T200019-20201116T050241.745000.nc")

# %%
check
# Out:
# <xarray.Dataset>
# Dimensions:                       (obs: 327498, wavelength: 78)
# Coordinates:
#   * obs                           (obs) int32 0 1 2 3 ... 327495 327496 327497
#   * wavelength                    (wavelength) int32 0 1 2 3 4 ... 74 75 76 77
# Data variables: (12/28)
#     external_temp_raw             (obs) float32 ...
#     c_signal_counts               (obs, wavelength) float32 ...
#     a_signal_counts               (obs, wavelength) float32 ...
#     a_reference_counts            (obs, wavelength) float32 ...
#     driver_timestamp              (obs) datetime64[ns] ...
#     id                            (obs) |S36 ...
#     ...                            ...
#     preferred_timestamp           (obs) object ...
#     a_signal_dark_counts          (obs) float32 ...
#     c_reference_counts            (obs, wavelength) float32 ...
#     a_reference_dark_counts       (obs) float32 ...
#     time                          (obs) datetime64[ns] ...
# ...

# %%
check.load()
# Out:
# <xarray.Dataset>
# Dimensions:                       (obs: 327498, wavelength: 78)
# Coordinates:
#   * obs                           (obs) int32 0 1 2 3 ... 327495 327496 327497
#   * wavelength                    (wavelength) int32 0 1 2 3 4 ... 74 75 76 77
# Data variables: (12/28)
#     external_temp_raw             (obs) float32 3.386e+04 ... 3.591e+04
#     c_signal_counts               (obs, wavelength) float32 572.0 ... 9.282e+03
#     a_signal_counts               (obs, wavelength) float32 307.0 ... 6.932e+03
#     a_reference_counts            (obs, wavelength) float32 553.0 ... 9.396e+03
#     driver_timestamp              (obs) datetime64[ns] 2021-06-11T10:32:39.80...
#     id                            (obs) |S36 b'44898a68-10d3-439b-83e4-42bc38...
#     ...                            ...
#     preferred_timestamp           (obs) object b'internal_timestamp' ... b'in...
#     a_signal_dark_counts          (obs) float32 688.0 689.0 ... 693.0 693.0
# ...
